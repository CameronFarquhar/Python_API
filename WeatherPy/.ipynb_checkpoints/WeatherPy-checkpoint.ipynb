# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#Generate Cities List

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_data = []

print('Beginning Data Retrieval\n-----------------------------\n')

rcd = 0 
sets = 1
for city in cities:
    
    rcd += 1
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        rcd = 0
        sets += 1
    
    query_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&clouds.value&units=imperial&appid={weather_api_key}"
    weather = requests.get(query_url).json()

    try:
        city_data.append({
            'City': city,
            'Lat': weather['coord']['lat'],
            'Lng': weather["coord"]['lon'],
            'Temp': weather["main"]["temp_max"],
            'Humidity': weather["main"]["humidity"],
            'Cloudiness': weather["clouds"]["all"],
            'Wind': weather["wind"]["speed"],
            'Country': weather["sys"]["country"],
            'Date': weather["dt"]
        })
    except:
        print('City not found. Skipping...')
        pass

print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | san roque
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | kozhva
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | juneau
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | plyussa
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | santa maria
# Processing Record 15 of Set 1 | natal
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | madras
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | the valley
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 1 | adrar
# Processing Record 34 of Set 1 | tazovskiy
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | lander
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | maniitsoq
# Processing Record 42 of Set 1 | oda
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | chuy
# Processing Record 45 of Set 1 | alofi
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | port hardy
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | sept-iles
# Processing Record 1 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | sribne
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | keffi
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | katherine
# Processing Record 9 of Set 2 | bossangoa
# Processing Record 10 of Set 2 | diego de almagro
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | verkhoyansk
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | kanniyakumari
# Processing Record 15 of Set 2 | evans
# Processing Record 16 of Set 2 | nhamunda
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | saint-joseph
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | victoria point
# Processing Record 22 of Set 2 | mildura
# Processing Record 23 of Set 2 | woodward
# Processing Record 24 of Set 2 | vila
# Processing Record 25 of Set 2 | lawton
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | urengoy
# Processing Record 28 of Set 2 | seybaplaya
# Processing Record 29 of Set 2 | edd
# Processing Record 30 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 2 | bosaso
# Processing Record 32 of Set 2 | vila velha
# Processing Record 33 of Set 2 | jalu
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | rapid valley
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | inhambane
# Processing Record 39 of Set 2 | eagle pass
# Processing Record 40 of Set 2 | waingapu
# Processing Record 41 of Set 2 | matagami
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | ialibu
# Processing Record 44 of Set 2 | horadiz
# Processing Record 45 of Set 2 | dicabisagan
# Processing Record 46 of Set 2 | saint-francois
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | lasa
# Processing Record 49 of Set 2 | najran
# Processing Record 50 of Set 2 | mayo
# Processing Record 1 of Set 3 | constitucion
# Processing Record 2 of Set 3 | vangaindrano
# Processing Record 3 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 3 | yulara
# Processing Record 5 of Set 3 | dengzhou
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | yar-sale
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | ylojarvi
# Processing Record 11 of Set 3 | pafos
# Processing Record 12 of Set 3 | omboue
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | ballina
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | kashi
# Processing Record 23 of Set 3 | svetlogorsk
# Processing Record 24 of Set 3 | buala
# Processing Record 25 of Set 3 | saint anthony
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | opuwo
# Processing Record 29 of Set 3 | rio gallegos
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | tottori
# Processing Record 32 of Set 3 | krasnik
# Processing Record 33 of Set 3 | kaniama
# Processing Record 34 of Set 3 | obo
# Processing Record 35 of Set 3 | cape canaveral
# Processing Record 36 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 3 | pozo colorado
# Processing Record 38 of Set 3 | nove zamky
# Processing Record 39 of Set 3 | san patricio
# Processing Record 40 of Set 3 | muros
# Processing Record 41 of Set 3 | dakar
# Processing Record 42 of Set 3 | fuerte olimpo
# Processing Record 43 of Set 3 | altay
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | that phanom
# Processing Record 46 of Set 3 | kailua
# Processing Record 47 of Set 3 | dingle
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | takoradi
# Processing Record 1 of Set 4 | callaway
# Processing Record 2 of Set 4 | terney
# Processing Record 3 of Set 4 | vestmannaeyjar
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | mbuguni
# Processing Record 7 of Set 4 | lodwar
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | clyde river
# Processing Record 11 of Set 4 | kieta
# Processing Record 12 of Set 4 | makakilo city
# Processing Record 13 of Set 4 | paamiut
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | tigil
# Processing Record 17 of Set 4 | tuktoyaktuk
# Processing Record 18 of Set 4 | burns lake
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | atar
# Processing Record 22 of Set 4 | acarau
# Processing Record 23 of Set 4 | mahebourg
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | vytegra
# Processing Record 26 of Set 4 | bara
# Processing Record 27 of Set 4 | moose factory
# Processing Record 28 of Set 4 | yarada
# Processing Record 29 of Set 4 | kutum
# Processing Record 30 of Set 4 | taoudenni
# Processing Record 31 of Set 4 | henties bay
# Processing Record 32 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 4 | bay-khaak
# Processing Record 35 of Set 4 | sedro-woolley
# Processing Record 36 of Set 4 | balakhninskiy
# Processing Record 37 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 4 | lagoa
# Processing Record 39 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 4 | khash
# Processing Record 41 of Set 4 | riyadh
# Processing Record 42 of Set 4 | alekseyevsk
# Processing Record 43 of Set 4 | shahrud
# Processing Record 44 of Set 4 | aljezur
# Processing Record 45 of Set 4 | hofn
# Processing Record 46 of Set 4 | marawi
# Processing Record 47 of Set 4 | harper
# Processing Record 48 of Set 4 | sur
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | carmelo
# Processing Record 1 of Set 5 | cayenne
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | pangnirtung
# Processing Record 4 of Set 5 | metro
# Processing Record 5 of Set 5 | skjervoy
# Processing Record 6 of Set 5 | juegang
# Processing Record 7 of Set 5 | labuhan
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | aquin
# Processing Record 11 of Set 5 | pacific grove
# Processing Record 12 of Set 5 | port hedland
# Processing Record 13 of Set 5 | nueva italia de ruiz
# Processing Record 14 of Set 5 | sao caetano de odivelas
# Processing Record 15 of Set 5 | balakovo
# Processing Record 16 of Set 5 | luanda
# Processing Record 17 of Set 5 | binzhou
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | vientiane
# Processing Record 20 of Set 5 | margate
# Processing Record 21 of Set 5 | champerico
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | riverton
# Processing Record 24 of Set 5 | kanker
# Processing Record 25 of Set 5 | sao joao del rei
# Processing Record 26 of Set 5 | maragogi
# Processing Record 27 of Set 5 | sfantu gheorghe
# Processing Record 28 of Set 5 | phan thiet
# Processing Record 29 of Set 5 | coalinga
# Processing Record 30 of Set 5 | puerto palomas
# Processing Record 31 of Set 5 | skibbereen
# Processing Record 32 of Set 5 | saint george
# Processing Record 33 of Set 5 | port macquarie
# Processing Record 34 of Set 5 | brae
# Processing Record 35 of Set 5 | tarnogskiy gorodok
# Processing Record 36 of Set 5 | taylor
# Processing Record 37 of Set 5 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 38 of Set 5 | saint-augustin
# Processing Record 39 of Set 5 | vale da amoreira
# Processing Record 40 of Set 5 | hornepayne
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | aswan
# Processing Record 43 of Set 5 | abu samrah
# Processing Record 44 of Set 5 | krasnoselkup
# Processing Record 45 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | waipawa
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | vitim
# Processing Record 49 of Set 5 | denpasar
# Processing Record 50 of Set 5 | graham
# Processing Record 1 of Set 6 | tomatlan
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | butaritari
# Processing Record 4 of Set 6 | chunoyar
# Processing Record 5 of Set 6 | arraial do cabo
# Processing Record 6 of Set 6 | acara
# Processing Record 7 of Set 6 | bokhan
# Processing Record 8 of Set 6 | general roca
# Processing Record 9 of Set 6 | narsaq
# Processing Record 10 of Set 6 | sao jose da coroa grande
# Processing Record 11 of Set 6 | yekaterinoslavka
# Processing Record 12 of Set 6 | ewa beach
# Processing Record 13 of Set 6 | norman wells
# Processing Record 14 of Set 6 | deming
# Processing Record 15 of Set 6 | along
# Processing Record 16 of Set 6 | benidorm
# Processing Record 17 of Set 6 | morgan city
# Processing Record 18 of Set 6 | russell
# Processing Record 19 of Set 6 | alta floresta
# Processing Record 20 of Set 6 | qaqortoq
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | pandamatenga
# Processing Record 23 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 6 | vanimo
# Processing Record 25 of Set 6 | talnakh
# Processing Record 26 of Set 6 | bilma
# Processing Record 27 of Set 6 | wajima
# Processing Record 28 of Set 6 | guiyang
# Processing Record 29 of Set 6 | mehamn
# Processing Record 30 of Set 6 | akdepe
# Processing Record 31 of Set 6 | visby
# Processing Record 32 of Set 6 | kaitangata
# Processing Record 33 of Set 6 | rameshki
# Processing Record 34 of Set 6 | acari
# Processing Record 35 of Set 6 | rochester
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | lavumisa
# Processing Record 38 of Set 6 | hirara
# Processing Record 39 of Set 6 | kruisfontein
# Processing Record 40 of Set 6 | mana
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 6 | novonukutskiy
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 6 | newcastle
# Processing Record 47 of Set 6 | handia
# Processing Record 48 of Set 6 | pozhva
# Processing Record 49 of Set 6 | agropoli
# Processing Record 50 of Set 6 | vieques
# Processing Record 1 of Set 7 | portland
# Processing Record 2 of Set 7 | coihaique
# Processing Record 3 of Set 7 | soyo
# Processing Record 4 of Set 7 | amboasary
# Processing Record 5 of Set 7 | sivakasi
# Processing Record 6 of Set 7 | izhmorskiy
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | salalah
# Processing Record 9 of Set 7 | kyabe
# Processing Record 10 of Set 7 | kaseda
# Processing Record 11 of Set 7 | mazyr
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | bima
# Processing Record 14 of Set 7 | zhigansk
# Processing Record 15 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 7 | sinnamary
# Processing Record 17 of Set 7 | porto novo
# Processing Record 18 of Set 7 | sovetskiy
# Processing Record 19 of Set 7 | catamarca
# Processing Record 20 of Set 7 | severo-kurilsk
# Processing Record 21 of Set 7 | solnechnyy
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | wisconsin rapids
# Processing Record 24 of Set 7 | abha
# Processing Record 25 of Set 7 | srandakan
# Processing Record 26 of Set 7 | mumford
# Processing Record 27 of Set 7 | matara
# Processing Record 28 of Set 7 | takoma park
# Processing Record 29 of Set 7 | aanekoski
# Processing Record 30 of Set 7 | pangody
# Processing Record 31 of Set 7 | burnie
# Processing Record 32 of Set 7 | rio grande
# Processing Record 33 of Set 7 | jiayuguan
# Processing Record 34 of Set 7 | mar del plata
# Processing Record 35 of Set 7 | outjo
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | guaruja
# Processing Record 38 of Set 7 | changji
# Processing Record 39 of Set 7 | gushikawa
# Processing Record 40 of Set 7 | pijijiapan
# Processing Record 41 of Set 7 | vostok
# Processing Record 42 of Set 7 | kununurra
# Processing Record 43 of Set 7 | bethel
# Processing Record 44 of Set 7 | khargone
# Processing Record 45 of Set 7 | luancheng
# Processing Record 46 of Set 7 | yinchuan
# Processing Record 47 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 7 | saint-leu
# Processing Record 50 of Set 7 | flin flon
# Processing Record 1 of Set 8 | bandundu
# Processing Record 2 of Set 8 | broome
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | batagay
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | isangel
# Processing Record 7 of Set 8 | miracema do tocantins
# Processing Record 8 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 8 | aranos
# Processing Record 10 of Set 8 | naze
# Processing Record 11 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 8 | samarai
# Processing Record 13 of Set 8 | gat
# Processing Record 14 of Set 8 | san policarpo
# Processing Record 15 of Set 8 | greenville
# Processing Record 16 of Set 8 | dublin
# Processing Record 17 of Set 8 | carutapera
# Processing Record 18 of Set 8 | sungaipenuh
# Processing Record 19 of Set 8 | karatuzskoye
# Processing Record 20 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 8 | barcelona
# Processing Record 22 of Set 8 | trairi
# Processing Record 23 of Set 8 | aksarka
# Processing Record 24 of Set 8 | maradi
# Processing Record 25 of Set 8 | zanjan
# Processing Record 26 of Set 8 | luba
# Processing Record 27 of Set 8 | college
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | meulaboh
# Processing Record 30 of Set 8 | nanortalik
# Processing Record 31 of Set 8 | kaoma
# Processing Record 32 of Set 8 | gravdal
# Processing Record 33 of Set 8 | loveland
# Processing Record 34 of Set 8 | tuatapere
# Processing Record 35 of Set 8 | winnemucca
# Processing Record 36 of Set 8 | dongsheng
# Processing Record 37 of Set 8 | mixtequilla
# City not found. Skipping...
# Processing Record 38 of Set 8 | santa isabel do rio negro
# Processing Record 39 of Set 8 | anadyr
# Processing Record 40 of Set 8 | payakumbuh
# Processing Record 41 of Set 8 | marrakesh
# Processing Record 42 of Set 8 | buritis
# Processing Record 43 of Set 8 | amarante do maranhao
# Processing Record 44 of Set 8 | rockhampton
# Processing Record 45 of Set 8 | new plymouth
# Processing Record 46 of Set 8 | san jeronimo
# Processing Record 47 of Set 8 | shetpe
# Processing Record 48 of Set 8 | kalmunai
# Processing Record 49 of Set 8 | kavieng
# Processing Record 50 of Set 8 | rondonopolis
# Processing Record 1 of Set 9 | grand-lahou
# Processing Record 2 of Set 9 | camapua
# Processing Record 3 of Set 9 | lubao
# Processing Record 4 of Set 9 | kuching
# Processing Record 5 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 9 | chagoda
# Processing Record 7 of Set 9 | we
# City not found. Skipping...
# Processing Record 8 of Set 9 | katsuura
# Processing Record 9 of Set 9 | yakeshi
# Processing Record 10 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 9 | cabadiangan
# Processing Record 12 of Set 9 | araouane
# Processing Record 13 of Set 9 | ipixuna
# Processing Record 14 of Set 9 | springfield
# Processing Record 15 of Set 9 | dwarka
# Processing Record 16 of Set 9 | santa rosa
# Processing Record 17 of Set 9 | rudsar
# Processing Record 18 of Set 9 | zamora
# Processing Record 19 of Set 9 | young
# Processing Record 20 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 9 | guirang
# Processing Record 22 of Set 9 | sangolqui
# Processing Record 23 of Set 9 | rock sound
# Processing Record 24 of Set 9 | evensk
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | tete
# Processing Record 27 of Set 9 | jacareacanga
# Processing Record 28 of Set 9 | synya
# Processing Record 29 of Set 9 | masuguru
# Processing Record 30 of Set 9 | waddan
# Processing Record 31 of Set 9 | shihezi
# Processing Record 32 of Set 9 | mudgee
# Processing Record 33 of Set 9 | namatanai
# Processing Record 34 of Set 9 | paita
# Processing Record 35 of Set 9 | antagan
# City not found. Skipping...
# Processing Record 36 of Set 9 | viedma
# Processing Record 37 of Set 9 | la queue-en-brie
# Processing Record 38 of Set 9 | padang
# Processing Record 39 of Set 9 | balikpapan
# Processing Record 40 of Set 9 | fort frances
# Processing Record 41 of Set 9 | chupa
# Processing Record 42 of Set 9 | zhigalovo
# Processing Record 43 of Set 9 | lucapa
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | wenzhou
# Processing Record 46 of Set 9 | comodoro rivadavia
# Processing Record 47 of Set 9 | oriximina
# Processing Record 48 of Set 9 | qui nhon
# Processing Record 49 of Set 9 | covington
# Processing Record 50 of Set 9 | gorontalo
# Processing Record 1 of Set 10 | urusha
# Processing Record 2 of Set 10 | rocha
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | clarksville
# Processing Record 5 of Set 10 | carauari
# Processing Record 6 of Set 10 | notse
# Processing Record 7 of Set 10 | paracelis
# Processing Record 8 of Set 10 | nioro
# Processing Record 9 of Set 10 | alice springs
# Processing Record 10 of Set 10 | calabozo
# Processing Record 11 of Set 10 | dandong
# Processing Record 12 of Set 10 | umm kaddadah
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | ulladulla
# Processing Record 15 of Set 10 | klaksvik
# Processing Record 16 of Set 10 | jumla
# Processing Record 17 of Set 10 | akcakoca
# Processing Record 18 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 10 | guerrero negro
# Processing Record 20 of Set 10 | porbandar
# Processing Record 21 of Set 10 | port hawkesbury
# Processing Record 22 of Set 10 | longyearbyen
# Processing Record 23 of Set 10 | tukrah
# Processing Record 24 of Set 10 | burica
# City not found. Skipping...
# Processing Record 25 of Set 10 | atasu
# Processing Record 26 of Set 10 | nicoya
# Processing Record 27 of Set 10 | huarmey
# Processing Record 28 of Set 10 | tumbagaan
# Processing Record 29 of Set 10 | hare bay
# Processing Record 30 of Set 10 | terrace
# Processing Record 31 of Set 10 | joensuu
# Processing Record 32 of Set 10 | elizabeth city
# Processing Record 33 of Set 10 | hervey bay
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | tura
# Processing Record 36 of Set 10 | bonfim
# Processing Record 37 of Set 10 | mungaa
# Processing Record 38 of Set 10 | ostrovnoy
# Processing Record 39 of Set 10 | kadur
# Processing Record 40 of Set 10 | sun prairie
# Processing Record 41 of Set 10 | mecca
# Processing Record 42 of Set 10 | mao
# Processing Record 43 of Set 10 | mareeba
# Processing Record 44 of Set 10 | shitanjing
# Processing Record 45 of Set 10 | kathu
# Processing Record 46 of Set 10 | maues
# Processing Record 47 of Set 10 | verkhniy avzyan
# Processing Record 48 of Set 10 | labrea
# Processing Record 49 of Set 10 | birjand
# Processing Record 50 of Set 10 | mionica
# Processing Record 1 of Set 11 | salamiyah
# Processing Record 2 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | san quintin
# Processing Record 5 of Set 11 | pokhara
# Processing Record 6 of Set 11 | awjilah
# Processing Record 7 of Set 11 | puerto colombia
# Processing Record 8 of Set 11 | fairbanks
# Processing Record 9 of Set 11 | woippy
# Processing Record 10 of Set 11 | roebourne
# Processing Record 11 of Set 11 | maan
# Processing Record 12 of Set 11 | nador
# Processing Record 13 of Set 11 | mogadishu
# Processing Record 14 of Set 11 | saint-junien
# Processing Record 15 of Set 11 | donghai
# Processing Record 16 of Set 11 | birao
# Processing Record 17 of Set 11 | egvekinot
# Processing Record 18 of Set 11 | kondinskoye
# Processing Record 19 of Set 11 | general pico
# Processing Record 20 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 11 | normandin
# Processing Record 22 of Set 11 | mujiayingzi
# Processing Record 23 of Set 11 | camp diable
# Processing Record 24 of Set 11 | homer
# Processing Record 25 of Set 11 | semnan
# Processing Record 26 of Set 11 | da nang
# Processing Record 27 of Set 11 | serbanesti
# Processing Record 28 of Set 11 | neyshabur
# Processing Record 29 of Set 11 | karcag
# Processing Record 30 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 11 | ascension
# Processing Record 32 of Set 11 | sitka
# Processing Record 33 of Set 11 | barnstaple
# Processing Record 34 of Set 11 | banyumas
# Processing Record 35 of Set 11 | solikamsk
# Processing Record 36 of Set 11 | bubaque
# Processing Record 37 of Set 11 | vysokogornyy
# Processing Record 38 of Set 11 | camacha
# Processing Record 39 of Set 11 | sant feliu de guixols
# Processing Record 40 of Set 11 | muisne
# Processing Record 41 of Set 11 | vardo
# Processing Record 42 of Set 11 | puksoozero
# Processing Record 43 of Set 11 | shatsk
# Processing Record 44 of Set 11 | boca do acre
# Processing Record 45 of Set 11 | cortez
# Processing Record 46 of Set 11 | santa helena de goias
# Processing Record 47 of Set 11 | ouadda
# Processing Record 48 of Set 11 | tamandare
# Processing Record 49 of Set 11 | santa luzia
# Processing Record 50 of Set 11 | kalispell
# Processing Record 1 of Set 12 | carupano
# Processing Record 2 of Set 12 | mukhen
# Processing Record 3 of Set 12 | vaitape
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 12 | imeni poliny osipenko
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | montague
# Processing Record 9 of Set 12 | muzhi
# Processing Record 10 of Set 12 | parintins
# Processing Record 11 of Set 12 | shimoda
# Processing Record 12 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 12 | xinqing
# Processing Record 14 of Set 12 | maceio
# Processing Record 15 of Set 12 | marzuq
# Processing Record 16 of Set 12 | simbahan
# Processing Record 17 of Set 12 | kemise
# Processing Record 18 of Set 12 | gerash
# Processing Record 19 of Set 12 | ribeira grande
# Processing Record 20 of Set 12 | koumac
# Processing Record 21 of Set 12 | kamenka
# Processing Record 22 of Set 12 | itacare
# Processing Record 23 of Set 12 | trinidad
# Processing Record 24 of Set 12 | erzin
# Processing Record 25 of Set 12 | westport
# Processing Record 26 of Set 12 | san andres
# Processing Record 27 of Set 12 | athabasca
# Processing Record 28 of Set 12 | chirongui
# Processing Record 29 of Set 12 | sivas
# Processing Record 30 of Set 12 | chinsali
# Processing Record 31 of Set 12 | poum
# Processing Record 32 of Set 12 | shonguy
# Processing Record 33 of Set 12 | phuket
# Processing Record 34 of Set 12 | mitchell
# Processing Record 35 of Set 12 | mokhsogollokh
# Processing Record 36 of Set 12 | panguna
# Processing Record 37 of Set 12 | nagato
# Processing Record 38 of Set 12 | republic
# Processing Record 39 of Set 12 | wenling
# Processing Record 40 of Set 12 | lahaina
# Processing Record 41 of Set 12 | ilinskiy
# Processing Record 42 of Set 12 | svetlaya
# Processing Record 43 of Set 12 | tongchuan
# Processing Record 44 of Set 12 | dakoro
# Processing Record 45 of Set 12 | beyneu
# Processing Record 46 of Set 12 | nishihara
# Processing Record 47 of Set 12 | komsomolskiy
# Processing Record 48 of Set 12 | port keats
# Processing Record 49 of Set 12 | rosario
# Processing Record 50 of Set 12 | kenai
# Processing Record 1 of Set 13 | kawalu
# Processing Record 2 of Set 13 | whitehorse
# Processing Record 3 of Set 13 | pevek
# Processing Record 4 of Set 13 | qianan
# Processing Record 5 of Set 13 | leshukonskoye
# Processing Record 6 of Set 13 | half moon bay
# Processing Record 7 of Set 13 | king city
# Processing Record 8 of Set 13 | bardiyah
# Processing Record 9 of Set 13 | vestmanna
# Processing Record 10 of Set 13 | santa barbara
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | filomeno mata
# Processing Record 13 of Set 13 | tortoli
# Processing Record 14 of Set 13 | canutama
# Processing Record 15 of Set 13 | kasese
# Processing Record 16 of Set 13 | kastamonu
# Processing Record 17 of Set 13 | quchan
# Processing Record 18 of Set 13 | colesberg
# Processing Record 19 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 13 | bocanda
# Processing Record 21 of Set 13 | morondava
# Processing Record 22 of Set 13 | port augusta
# Processing Record 23 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 13 | la crosse
# Processing Record 25 of Set 13 | dosso
# Processing Record 26 of Set 13 | boa vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(city_data)
df.to_csv(output_data_file)
df
# Out:
#                City      Lat       Lng   Temp  Humidity  Cloudiness   Wind  \
# 0         san roque  36.2107   -5.3842  59.00        67          75  13.80
# 1          bengkulu  -3.8004  102.2655  76.48        85          72   4.85
# 2            kozhva  65.1073   57.0459  -8.05        91          99   8.21
# 3           rikitea -23.1203 -134.9692  78.80        69           0  10.65
# 4    saint-philippe -21.3585   55.7679  80.60        65           0   5.75
# ..              ...      ...       ...    ...       ...         ...    ...
# 576       morondava -20.2833   44.2833  82.87        82         100  10.38
# 577    port augusta -32.5000  137.7667  64.40        77          90   6.91
# 578       la crosse  43.8014  -91.2396  12.00        61          75  24.16
# 579           dosso  13.0490    3.1937  82.45        15           0   8.77
# 580       boa vista   2.8197  -60.6733  87.80        51          90  14.97
#
#     Country        Date
# 0        ES  1612551867
# 1        ID  1612551690
# 2        RU  1612551867
# 3        PF  1612551794
# 4        RE  1612551683
# ..      ...         ...
# 576      MG  1612551684
# 577      AU  1612551938
# 578      US  1612551938
# 579      NE  1612551938
# 580      BR  1612551938
#
# [581 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
df.describe()
# Out:
#               Lat         Lng        Temp    Humidity  Cloudiness        Wind  \
# count  581.000000  581.000000  581.000000  581.000000  581.000000  581.000000
# mean    19.641678   15.154949   52.180052   71.111876   51.117040    8.095680
# std     32.514682   91.006945   31.796695   21.340738   40.661471    5.337366
# min    -54.800000 -179.166700  -41.550000   12.000000    0.000000    0.380000
# 25%     -6.884400  -64.798100   35.010000   60.000000    1.000000    3.960000
# 50%     22.678300   21.286900   62.010000   77.000000   59.000000    6.910000
# 75%     45.523400  100.335400   77.000000   87.000000   90.000000   11.450000
# max     78.218600  179.316700  102.990000  100.000000  100.000000   28.770000
#
#                Date
# count  5.810000e+02
# mean   1.612552e+09
# std    9.409210e+01
# min    1.612552e+09
# 25%    1.612552e+09
# 50%    1.612552e+09
# 75%    1.612552e+09
# max    1.612552e+09

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(df["Lat"], df["Temp"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

curr_date = pd.to_datetime('today').date()

plt.xlim(df["Lat"].min()-3, df["Lat"].max()+3)
plt.ylim(df["Temp"].min()-3, df["Temp"].max()+3)

plt.title(f"City Latitude vs. Max Temperature ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)
plt.savefig('output_data/lat_v_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(df["Lat"], df["Humidity"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.xlim(df["Lat"].min()-3, df["Lat"].max()+3)
plt.ylim(df["Humidity"].min()-3, df["Humidity"].max()+3)

plt.title(f"City Latitude vs. Humidity ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)
plt.savefig('output_data/lat_v_hum.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Lat"], df["Cloudiness"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.xlim(df["Lat"].min()-5, df["Lat"].max()+5)
plt.ylim(df["Cloudiness"].min()-5, df["Cloudiness"].max()+5)

plt.title(f"City Latitude vs. Cloudiness ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)
plt.savefig('output_data/lat_v_cloud.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Lat"], df["Wind"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.xlim(df["Lat"].min()-5, df["Lat"].max()+5)
plt.ylim(df["Wind"].min()-5, df["Wind"].max()+5)

plt.title(f"City Latitude vs. Wind Speed ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)
plt.savefig('output_data/lat_v_wind.png')

# %% [markdown]
# ## Linear Regression

# %%
north_hem_df = df.loc[df["Lat"] >=0]
south_hem_df = df.loc[df["Lat"] <0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hem_df["Lat"]
y_values = north_hem_df["Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(0,-10), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Max Temperature ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_temp_N.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.7822226566604631

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hem_df["Lat"]
y_values = south_hem_df["Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r")

plt.annotate(line_eq,(-25,50),fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Max Temperature ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_temp_S.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.22951108754486488

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hem_df["Lat"]
y_values = north_hem_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(38,15), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Humidity (%) ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_hum_N.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.14244196044140042

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hem_df["Lat"]
y_values = south_hem_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-30,15), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Humidity (%) ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_hum_S.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.020319345217105076

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hem_df["Lat"]
y_values = north_hem_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(45,40), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Cloudiness(%) ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_cloud_N.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.11267589225941489

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hem_df["Lat"]
y_values = south_hem_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-55,20), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Cloudiness(%) ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_cloud_S.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.049373955167918336

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hem_df["Lat"]
y_values = north_hem_df["Wind"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(5,21), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Windiness (mph) ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Windiness")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_wind_N.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.0003991468914553655

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hem_df["Lat"]
y_values = south_hem_df["Wind"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-35,27), fontsize=15,color="red")

plt.xlim(x_values.min()-3, x_values.max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Windiness (mph) ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Windiness")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

plt.savefig('output_data/lat_v_wind_S.png')

print(f'the r-value is: {rvalue**2}')
# Out:
# the r-value is: 0.04847884424598942
