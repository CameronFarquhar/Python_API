# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_data = []

print('Beginning Data Retrieval\n-----------------------------\n')

rcd = 0 
sets = 1
for city in cities:
    rcd += 1
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        rcd = 0
        sets += 1
    
    query_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&clouds.value&units=imperial&appid={weather_api_key}"
    weather = requests.get(query_url).json()

    try:
        city_data.append({
            'City': city,
            'Lat': weather['coord']['lat'],
            'Lng': weather["coord"]['lon'],
            'Temp': weather["main"]["temp_max"],
            'Humidity': weather["main"]["humidity"],
            'Cloudiness': weather["clouds"]["all"],
            'Wind': weather["wind"]["speed"],
            'Country': weather["sys"]["country"],
            'Date': weather["dt"]
        })
    except:
        print('City not found. Skipping...')
        pass

print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
#
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | sobradinho
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ponta delgada
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | cockburn town
# Processing Record 12 of Set 1 | tela
# Processing Record 13 of Set 1 | sandwick
# Processing Record 14 of Set 1 | paris
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | almaznyy
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | darlowo
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | lewistown
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | the valley
# Processing Record 32 of Set 1 | alofi
# Processing Record 33 of Set 1 | madimba
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | sao jose dos pinhais
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | burica
# City not found. Skipping...
# Processing Record 38 of Set 1 | jackson
# Processing Record 39 of Set 1 | poso
# Processing Record 40 of Set 1 | kurumkan
# Processing Record 41 of Set 1 | cozumel
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | mayumba
# Processing Record 44 of Set 1 | bairnsdale
# Processing Record 45 of Set 1 | lasa
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | matagami
# Processing Record 49 of Set 1 | high level
# Processing Record 50 of Set 1 | saint-joseph
# Processing Record 1 of Set 2 | vostok
# Processing Record 2 of Set 2 | pishin
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | usinsk
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | oksfjord
# Processing Record 7 of Set 2 | tanshui
# City not found. Skipping...
# Processing Record 8 of Set 2 | tomari
# Processing Record 9 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 10 of Set 2 | kharp
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | alamogordo
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | el alto
# Processing Record 16 of Set 2 | christchurch
# Processing Record 17 of Set 2 | suntar
# Processing Record 18 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | songea
# Processing Record 21 of Set 2 | yarensk
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | cap-aux-meules
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | naze
# Processing Record 26 of Set 2 | dingle
# Processing Record 27 of Set 2 | cartagena
# Processing Record 28 of Set 2 | kieta
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | acari
# Processing Record 32 of Set 2 | beringovskiy
# Processing Record 33 of Set 2 | saint-paul
# Processing Record 34 of Set 2 | tambacounda
# Processing Record 35 of Set 2 | saint-augustin
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | kangaatsiaq
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | mildura
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | miyako
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | amga
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | sinnamary
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | sorland
# Processing Record 5 of Set 3 | macau
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | alta floresta
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | pasni
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | hingatungan
# Processing Record 13 of Set 3 | karatau
# Processing Record 14 of Set 3 | kaminskiy
# Processing Record 15 of Set 3 | halifax
# Processing Record 16 of Set 3 | balabac
# Processing Record 17 of Set 3 | kyra
# Processing Record 18 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 3 | sobolevo
# Processing Record 20 of Set 3 | kiomboi
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | tambopata
# Processing Record 24 of Set 3 | lazaro cardenas
# Processing Record 25 of Set 3 | singkang
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | ust-nera
# Processing Record 28 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 29 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | suclayin
# Processing Record 33 of Set 3 | gornopravdinsk
# Processing Record 34 of Set 3 | san carlos de bariloche
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | srednekolymsk
# Processing Record 37 of Set 3 | fukue
# Processing Record 38 of Set 3 | dhola
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | aleksandrov gay
# Processing Record 41 of Set 3 | eureka
# Processing Record 42 of Set 3 | fare
# Processing Record 43 of Set 3 | ambovombe
# Processing Record 44 of Set 3 | hirara
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | jalu
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | tavda
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | berdigestyakh
# Processing Record 2 of Set 4 | pacific grove
# Processing Record 3 of Set 4 | leningradskiy
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | rudnogorsk
# Processing Record 6 of Set 4 | maun
# Processing Record 7 of Set 4 | taltal
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | seinajoki
# Processing Record 10 of Set 4 | suraabad
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | deputatskiy
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | mumford
# Processing Record 16 of Set 4 | poum
# Processing Record 17 of Set 4 | kazachinskoye
# Processing Record 18 of Set 4 | honningsvag
# Processing Record 19 of Set 4 | brokopondo
# Processing Record 20 of Set 4 | uhlove
# Processing Record 21 of Set 4 | pemangkat
# Processing Record 22 of Set 4 | jinchang
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | kostomuksha
# Processing Record 26 of Set 4 | shellbrook
# Processing Record 27 of Set 4 | aizpute
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | ambatolampy
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | hermanus
# Processing Record 37 of Set 4 | oromocto
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | salgueiro
# Processing Record 40 of Set 4 | monrovia
# Processing Record 41 of Set 4 | tanabe
# Processing Record 42 of Set 4 | knysna
# Processing Record 43 of Set 4 | zyryanka
# Processing Record 44 of Set 4 | alexandria
# Processing Record 45 of Set 4 | tigzirt
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | baghdad
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | labuan
# Processing Record 50 of Set 4 | hasaki
# Processing Record 1 of Set 5 | mount gambier
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 5 | mogadishu
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | port hedland
# Processing Record 8 of Set 5 | woodward
# Processing Record 9 of Set 5 | wuwei
# Processing Record 10 of Set 5 | huarmey
# Processing Record 11 of Set 5 | amazar
# Processing Record 12 of Set 5 | kudahuvadhoo
# Processing Record 13 of Set 5 | anadyr
# Processing Record 14 of Set 5 | wajir
# Processing Record 15 of Set 5 | gaoual
# Processing Record 16 of Set 5 | chirilagua
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | port hardy
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | charters towers
# Processing Record 21 of Set 5 | adrar
# Processing Record 22 of Set 5 | ripoll
# Processing Record 23 of Set 5 | krasne
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | ouesso
# Processing Record 26 of Set 5 | labuhan
# Processing Record 27 of Set 5 | dwarka
# Processing Record 28 of Set 5 | makum
# Processing Record 29 of Set 5 | finschhafen
# Processing Record 30 of Set 5 | lappeenranta
# Processing Record 31 of Set 5 | chicama
# Processing Record 32 of Set 5 | ugoofaaru
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | kyabe
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | tuktoyaktuk
# Processing Record 37 of Set 5 | lata
# Processing Record 38 of Set 5 | paamiut
# Processing Record 39 of Set 5 | ilanskiy
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | port macquarie
# Processing Record 42 of Set 5 | corinto
# Processing Record 43 of Set 5 | naruto
# Processing Record 44 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 5 | nara
# Processing Record 46 of Set 5 | damghan
# Processing Record 47 of Set 5 | baruun-urt
# Processing Record 48 of Set 5 | chihuahua
# Processing Record 49 of Set 5 | saint-georges
# Processing Record 50 of Set 5 | pointe-noire
# Processing Record 1 of Set 6 | marystown
# Processing Record 2 of Set 6 | te anau
# Processing Record 3 of Set 6 | anchorage
# Processing Record 4 of Set 6 | morondava
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | port lincoln
# Processing Record 7 of Set 6 | pouembout
# Processing Record 8 of Set 6 | roald
# Processing Record 9 of Set 6 | les escoumins
# Processing Record 10 of Set 6 | mehamn
# Processing Record 11 of Set 6 | aklavik
# Processing Record 12 of Set 6 | sainte-marie
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | malmesbury
# Processing Record 15 of Set 6 | rostaq
# City not found. Skipping...
# Processing Record 16 of Set 6 | mbandaka
# Processing Record 17 of Set 6 | okha
# Processing Record 18 of Set 6 | atambua
# Processing Record 19 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 6 | sur
# Processing Record 21 of Set 6 | santa vitoria do palmar
# Processing Record 22 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | colmenar viejo
# Processing Record 25 of Set 6 | saint-philippe
# Processing Record 26 of Set 6 | rypefjord
# Processing Record 27 of Set 6 | abyek
# Processing Record 28 of Set 6 | haines junction
# Processing Record 29 of Set 6 | kanniyakumari
# Processing Record 30 of Set 6 | kathu
# Processing Record 31 of Set 6 | yerbogachen
# Processing Record 32 of Set 6 | yellowknife
# Processing Record 33 of Set 6 | norman wells
# Processing Record 34 of Set 6 | truth or consequences
# Processing Record 35 of Set 6 | sayat
# Processing Record 36 of Set 6 | hainburg
# Processing Record 37 of Set 6 | fairbanks
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | tete
# Processing Record 40 of Set 6 | castro
# Processing Record 41 of Set 6 | tilichiki
# Processing Record 42 of Set 6 | leh
# Processing Record 43 of Set 6 | anlu
# Processing Record 44 of Set 6 | oranjemund
# Processing Record 45 of Set 6 | matay
# Processing Record 46 of Set 6 | boa vista
# Processing Record 47 of Set 6 | ulaanbaatar
# Processing Record 48 of Set 6 | hohhot
# Processing Record 49 of Set 6 | semey
# Processing Record 50 of Set 6 | olafsvik
# Processing Record 1 of Set 7 | lorengau
# Processing Record 2 of Set 7 | guerrero negro
# Processing Record 3 of Set 7 | sarny
# Processing Record 4 of Set 7 | sydney
# Processing Record 5 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 7 | wadi maliz
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | madridejos
# Processing Record 9 of Set 7 | inhambane
# Processing Record 10 of Set 7 | egvekinot
# Processing Record 11 of Set 7 | bilma
# Processing Record 12 of Set 7 | hambantota
# Processing Record 13 of Set 7 | byron bay
# Processing Record 14 of Set 7 | carahue
# Processing Record 15 of Set 7 | kavaratti
# Processing Record 16 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | general roca
# Processing Record 18 of Set 7 | barra do garcas
# Processing Record 19 of Set 7 | puri
# Processing Record 20 of Set 7 | sergeyevka
# Processing Record 21 of Set 7 | nikki
# Processing Record 22 of Set 7 | krasnoselkup
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | rosarito
# Processing Record 25 of Set 7 | omsukchan
# Processing Record 26 of Set 7 | asau
# Processing Record 27 of Set 7 | san patricio
# Processing Record 28 of Set 7 | qui nhon
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | peterhead
# Processing Record 31 of Set 7 | juegang
# Processing Record 32 of Set 7 | shingu
# Processing Record 33 of Set 7 | birin
# Processing Record 34 of Set 7 | wamba
# Processing Record 35 of Set 7 | katherine
# Processing Record 36 of Set 7 | cherskiy
# Processing Record 37 of Set 7 | vardo
# Processing Record 38 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 7 | giresun
# Processing Record 40 of Set 7 | ambon
# Processing Record 41 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 42 of Set 7 | black river
# Processing Record 43 of Set 7 | ulaangom
# Processing Record 44 of Set 7 | dauphin
# Processing Record 45 of Set 7 | tak
# Processing Record 46 of Set 7 | sibu
# Processing Record 47 of Set 7 | husavik
# Processing Record 48 of Set 7 | hammerfest
# Processing Record 49 of Set 7 | maues
# Processing Record 50 of Set 7 | ossora
# Processing Record 1 of Set 8 | avarua
# Processing Record 2 of Set 8 | ilebo
# Processing Record 3 of Set 8 | caravelas
# Processing Record 4 of Set 8 | pisco
# Processing Record 5 of Set 8 | yaring
# Processing Record 6 of Set 8 | margate
# Processing Record 7 of Set 8 | raudeberg
# Processing Record 8 of Set 8 | uyuni
# Processing Record 9 of Set 8 | kenai
# Processing Record 10 of Set 8 | lavrentiya
# Processing Record 11 of Set 8 | trelew
# Processing Record 12 of Set 8 | ballina
# Processing Record 13 of Set 8 | ushtobe
# Processing Record 14 of Set 8 | kaniama
# Processing Record 15 of Set 8 | bowen
# Processing Record 16 of Set 8 | nakusp
# Processing Record 17 of Set 8 | saint george
# Processing Record 18 of Set 8 | vanavara
# Processing Record 19 of Set 8 | lompoc
# Processing Record 20 of Set 8 | buncrana
# Processing Record 21 of Set 8 | conde
# Processing Record 22 of Set 8 | kamaishi
# Processing Record 23 of Set 8 | plouzane
# Processing Record 24 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 8 | datong
# Processing Record 26 of Set 8 | wiwili
# Processing Record 27 of Set 8 | lujan
# Processing Record 28 of Set 8 | beira
# Processing Record 29 of Set 8 | victoria
# Processing Record 30 of Set 8 | namatanai
# Processing Record 31 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 32 of Set 8 | along
# Processing Record 33 of Set 8 | maniitsoq
# Processing Record 34 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 8 | ixtapa
# Processing Record 36 of Set 8 | bathsheba
# Processing Record 37 of Set 8 | nemuro
# Processing Record 38 of Set 8 | clydebank
# Processing Record 39 of Set 8 | baykit
# Processing Record 40 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 8 | eufaula
# Processing Record 42 of Set 8 | wau
# Processing Record 43 of Set 8 | lugovoy
# Processing Record 44 of Set 8 | belmonte
# Processing Record 45 of Set 8 | inongo
# Processing Record 46 of Set 8 | kilindoni
# Processing Record 47 of Set 8 | qinhuangdao
# Processing Record 48 of Set 8 | portland
# Processing Record 49 of Set 8 | galesong
# Processing Record 50 of Set 8 | sao jose da coroa grande
# Processing Record 1 of Set 9 | falun
# Processing Record 2 of Set 9 | dubbo
# Processing Record 3 of Set 9 | mantua
# Processing Record 4 of Set 9 | san francisco
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | port blair
# Processing Record 7 of Set 9 | sabang
# Processing Record 8 of Set 9 | comodoro rivadavia
# Processing Record 9 of Set 9 | qena
# Processing Record 10 of Set 9 | yulara
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 9 | kotka
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | necochea
# Processing Record 16 of Set 9 | glenluce
# Processing Record 17 of Set 9 | mareeba
# Processing Record 18 of Set 9 | hami
# Processing Record 19 of Set 9 | winnemucca
# Processing Record 20 of Set 9 | guiren
# Processing Record 21 of Set 9 | preobrazheniye
# Processing Record 22 of Set 9 | play cu
# City not found. Skipping...
# Processing Record 23 of Set 9 | antsohihy
# Processing Record 24 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 9 | mapastepec
# Processing Record 26 of Set 9 | san cristobal
# Processing Record 27 of Set 9 | akdepe
# Processing Record 28 of Set 9 | miedzychod
# Processing Record 29 of Set 9 | mandalgovi
# Processing Record 30 of Set 9 | kitimat
# Processing Record 31 of Set 9 | krasnoarmeyskoye
# Processing Record 32 of Set 9 | sao filipe
# Processing Record 33 of Set 9 | praya
# Processing Record 34 of Set 9 | maldonado
# Processing Record 35 of Set 9 | archidona
# Processing Record 36 of Set 9 | pangnirtung
# Processing Record 37 of Set 9 | tagbac
# Processing Record 38 of Set 9 | henties bay
# Processing Record 39 of Set 9 | durango
# Processing Record 40 of Set 9 | ust-maya
# Processing Record 41 of Set 9 | barvinkove
# Processing Record 42 of Set 9 | zangakatun
# Processing Record 43 of Set 9 | ulladulla
# Processing Record 44 of Set 9 | inirida
# Processing Record 45 of Set 9 | mecca
# Processing Record 46 of Set 9 | panshi
# Processing Record 47 of Set 9 | poya
# Processing Record 48 of Set 9 | terrace
# Processing Record 49 of Set 9 | pauini
# Processing Record 50 of Set 9 | skjervoy
# Processing Record 1 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 2 of Set 10 | wanning
# Processing Record 3 of Set 10 | batemans bay
# Processing Record 4 of Set 10 | ocna de fier
# Processing Record 5 of Set 10 | tumut
# Processing Record 6 of Set 10 | jacareacanga
# Processing Record 7 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 10 | pundaguitan
# Processing Record 9 of Set 10 | samagaltay
# Processing Record 10 of Set 10 | flinders
# Processing Record 11 of Set 10 | katsuura
# Processing Record 12 of Set 10 | wenling
# Processing Record 13 of Set 10 | nanortalik
# Processing Record 14 of Set 10 | oranjestad
# Processing Record 15 of Set 10 | kholm-zhirkovskiy
# Processing Record 16 of Set 10 | faya
# Processing Record 17 of Set 10 | sirjan
# Processing Record 18 of Set 10 | komsomolskiy
# Processing Record 19 of Set 10 | linfen
# Processing Record 20 of Set 10 | mayo
# Processing Record 21 of Set 10 | panaba
# Processing Record 22 of Set 10 | ahipara
# Processing Record 23 of Set 10 | saint anthony
# Processing Record 24 of Set 10 | ambulu
# Processing Record 25 of Set 10 | mikropolis
# Processing Record 26 of Set 10 | zaozerne
# Processing Record 27 of Set 10 | calvinia
# Processing Record 28 of Set 10 | belyy yar
# Processing Record 29 of Set 10 | kibre mengist
# Processing Record 30 of Set 10 | manoel urbano
# Processing Record 31 of Set 10 | nehe
# Processing Record 32 of Set 10 | ust-kuyga
# Processing Record 33 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 10 | bilibino
# Processing Record 36 of Set 10 | boralday
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | cap malheureux
# Processing Record 39 of Set 10 | axim
# Processing Record 40 of Set 10 | port augusta
# Processing Record 41 of Set 10 | phan thiet
# Processing Record 42 of Set 10 | ingham
# Processing Record 43 of Set 10 | gubkinskiy
# Processing Record 44 of Set 10 | shache
# Processing Record 45 of Set 10 | beaufort
# Processing Record 46 of Set 10 | half moon bay
# Processing Record 47 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 10 | starozhilovo
# Processing Record 49 of Set 10 | truckee
# Processing Record 50 of Set 10 | burnie
# Processing Record 1 of Set 11 | chapais
# Processing Record 2 of Set 11 | uribia
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | honiara
# Processing Record 5 of Set 11 | trairi
# Processing Record 6 of Set 11 | faanui
# Processing Record 7 of Set 11 | micomeseng
# Processing Record 8 of Set 11 | ouadda
# Processing Record 9 of Set 11 | yarqa
# Processing Record 10 of Set 11 | kruisfontein
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | dabat
# Processing Record 13 of Set 11 | kirundo
# Processing Record 14 of Set 11 | kupang
# Processing Record 15 of Set 11 | chiang khong
# Processing Record 16 of Set 11 | boysun
# Processing Record 17 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 11 | ikungi
# Processing Record 19 of Set 11 | toktogul
# Processing Record 20 of Set 11 | rawlins
# Processing Record 21 of Set 11 | bom jardim
# Processing Record 22 of Set 11 | inverness
# Processing Record 23 of Set 11 | bilopillya
# Processing Record 24 of Set 11 | linxia
# Processing Record 25 of Set 11 | cayenne
# Processing Record 26 of Set 11 | cacoal
# Processing Record 27 of Set 11 | zhezkazgan
# Processing Record 28 of Set 11 | cayhagan
# Processing Record 29 of Set 11 | yenagoa
# Processing Record 30 of Set 11 | pietarsaari
# Processing Record 31 of Set 11 | sonari
# Processing Record 32 of Set 11 | kosonsoy
# Processing Record 33 of Set 11 | hobyo
# Processing Record 34 of Set 11 | taveta
# Processing Record 35 of Set 11 | tautira
# Processing Record 36 of Set 11 | namuac
# Processing Record 37 of Set 11 | san jeronimo
# Processing Record 38 of Set 11 | bonaventure
# Processing Record 39 of Set 11 | arlit
# Processing Record 40 of Set 11 | yuli
# Processing Record 41 of Set 11 | macomb
# Processing Record 42 of Set 11 | montevideo
# Processing Record 43 of Set 11 | chekhov
# Processing Record 44 of Set 11 | kemijarvi
# Processing Record 45 of Set 11 | ayan
# Processing Record 46 of Set 11 | northam
# Processing Record 47 of Set 11 | constantine
# Processing Record 48 of Set 11 | timmins
# Processing Record 49 of Set 11 | saskylakh
# Processing Record 50 of Set 11 | manaure
# Processing Record 1 of Set 12 | japura
# Processing Record 2 of Set 12 | vaitape
# Processing Record 3 of Set 12 | astakos
# Processing Record 4 of Set 12 | cutler ridge
# Processing Record 5 of Set 12 | dadu
# Processing Record 6 of Set 12 | nabire
# Processing Record 7 of Set 12 | barcelos
# Processing Record 8 of Set 12 | pilar
# Processing Record 9 of Set 12 | wattegama
# Processing Record 10 of Set 12 | adre
# Processing Record 11 of Set 12 | kiruna
# Processing Record 12 of Set 12 | plettenberg bay
# Processing Record 13 of Set 12 | linhai
# Processing Record 14 of Set 12 | sangar
# Processing Record 15 of Set 12 | tazovskiy
# Processing Record 16 of Set 12 | dongsheng
# Processing Record 17 of Set 12 | lucapa
# Processing Record 18 of Set 12 | acapulco
# Processing Record 19 of Set 12 | milkovo
# Processing Record 20 of Set 12 | ermelo
# Processing Record 21 of Set 12 | arenapolis
# Processing Record 22 of Set 12 | tungor
# Processing Record 23 of Set 12 | beisfjord
# Processing Record 24 of Set 12 | sesheke
# Processing Record 25 of Set 12 | merauke
# Processing Record 26 of Set 12 | pontes e lacerda
# Processing Record 27 of Set 12 | bam
# Processing Record 28 of Set 12 | miguel calmon
# Processing Record 29 of Set 12 | ongandjera
# Processing Record 30 of Set 12 | port-gentil
# Processing Record 31 of Set 12 | jerantut
# Processing Record 32 of Set 12 | yeppoon
# Processing Record 33 of Set 12 | manzhouli
# Processing Record 34 of Set 12 | revda
# Processing Record 35 of Set 12 | bulawayo
# Processing Record 36 of Set 12 | neuquen
# Processing Record 37 of Set 12 | salalah
# Processing Record 38 of Set 12 | sioux lookout
# Processing Record 39 of Set 12 | najran
# Processing Record 40 of Set 12 | pedro ii
# Processing Record 41 of Set 12 | sorong
# Processing Record 42 of Set 12 | sakakah
# Processing Record 43 of Set 12 | eregli
# Processing Record 44 of Set 12 | road town
# Processing Record 45 of Set 12 | limulunga
# Processing Record 46 of Set 12 | mountain home
# Processing Record 47 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 12 | muros
# Processing Record 49 of Set 12 | sambava
# Processing Record 50 of Set 12 | naryan-mar
# Processing Record 1 of Set 13 | college
# Processing Record 2 of Set 13 | piastow
# Processing Record 3 of Set 13 | bijie
# Processing Record 4 of Set 13 | moose factory
# Processing Record 5 of Set 13 | komsomolets
# Processing Record 6 of Set 13 | thinadhoo
# Processing Record 7 of Set 13 | amapa
# Processing Record 8 of Set 13 | huron
# Processing Record 9 of Set 13 | nome
# Processing Record 10 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 13 | bathurst
# Processing Record 12 of Set 13 | ofaqim
# Processing Record 13 of Set 13 | sao joao do piaui
# Processing Record 14 of Set 13 | vestmanna
# Processing Record 15 of Set 13 | nikolayevsk-na-amure
# Processing Record 16 of Set 13 | hualmay
# Processing Record 17 of Set 13 | kichera
# Processing Record 18 of Set 13 | nuristan
# Processing Record 19 of Set 13 | nuuk
# Processing Record 20 of Set 13 | eindhoven
# Processing Record 21 of Set 13 | mumbwa
# Processing Record 22 of Set 13 | samfya
# Processing Record 23 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 24 of Set 13 | banda aceh
# Processing Record 25 of Set 13 | rundu
# Processing Record 26 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 27 of Set 13 | lamu
# Processing Record 28 of Set 13 | boende
# Processing Record 29 of Set 13 | ruidoso
# Processing Record 30 of Set 13 | ramjibanpur
# Processing Record 31 of Set 13 | mansa
# Processing Record 32 of Set 13 | ipixuna
# Processing Record 33 of Set 13 | san juan
# Processing Record 34 of Set 13 | tessalit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# city_data.to_csv(output_data_file)
df = pd.DataFrame(city_data)
df.to_csv(output_data_file)
df
# Out:
#              City      Lat       Lng   Temp  Humidity  Cloudiness   Wind  \
# 0            hilo  19.7297 -155.0900  75.20        60           1   4.61
# 1       carnarvon -24.8667  113.6333  75.20       100          40  21.85
# 2    punta arenas -53.1500  -70.9167  69.80        49          40  17.00
# 3         ushuaia -54.8000  -68.3000  53.60        82          75  14.97
# 4      sobradinho -12.8333  -39.1000  84.02        63          55   9.44
# ..            ...      ...       ...    ...       ...         ...    ...
# 587   ramjibanpur  22.8333   87.6167  55.22        43           0   3.40
# 588         mansa  29.9833   75.3833  56.46        39           0   6.08
# 589       ipixuna  -1.7625  -48.8043  89.60        58          75  10.36
# 590      san juan -31.5375  -68.5364  73.40        33          93  11.59
# 591      tessalit  20.1986    1.0114  71.76        19          23   8.84
#
#     Country        Date
# 0        US  1612293749
# 1        AU  1612293830
# 2        CL  1612293567
# 3        AR  1612293808
# 4        BR  1612293830
# ..      ...         ...
# 587      IN  1612293902
# 588      IN  1612293902
# 589      BR  1612293902
# 590      AR  1612293769
# 591      ML  1612293903
#
# [592 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
df.describe()
# Out:
#               Lat         Lng        Temp    Humidity  Cloudiness        Wind  \
# count  592.000000  592.000000  592.000000  592.000000  592.000000  592.000000
# mean    20.483597   23.604847   49.217838   73.854730   52.491554    8.663598
# std     34.081330   89.655736   33.398342   19.679217   41.261002    6.291090
# min    -54.800000 -179.166700  -42.740000   12.000000    0.000000    0.090000
# 25%     -8.141900  -55.152900   26.817500   64.000000    1.000000    3.885000
# 50%     25.549050   27.003850   59.710000   79.000000   61.500000    6.910000
# 75%     50.003725  102.680900   77.170000   88.000000   96.250000   11.522500
# max     78.218600  179.316700   96.800000  100.000000  100.000000   43.660000
#
#                Date
# count  5.920000e+02
# mean   1.612294e+09
# std    6.547820e+01
# min    1.612294e+09
# 25%    1.612294e+09
# 50%    1.612294e+09
# 75%    1.612294e+09
# max    1.612294e+09

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(df["Lat"], df["Temp"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

curr_date = pd.to_datetime('today').date()

plt.xlim(df["Lat"].min()-3, df["Lat"].max()+3)
plt.ylim(df["Temp"].min()-3, df["Temp"].max()+3)

plt.title(f"City Latitude vs. Max Temperature ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(df["Lat"], df["Humidity"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.xlim(df["Lat"].min()-3, df["Lat"].max()+3)
plt.ylim(df["Humidity"].min()-3, df["Humidity"].max()+3)

plt.title(f"City Latitude vs. Humidity ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Lat"], df["Cloudiness"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.xlim(df["Lat"].min()-5, df["Lat"].max()+5)
plt.ylim(df["Cloudiness"].min()-5, df["Cloudiness"].max()+5)

plt.title(f"City Latitude vs. Cloudiness ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Lat"], df["Wind"], marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.xlim(df["Lat"].min()-5, df["Lat"].max()+5)
plt.ylim(df["Wind"].min()-5, df["Wind"].max()+5)

plt.title(f"City Latitude vs. Wind Speed ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

# %% [markdown]
# ## Linear Regression

# %%
x_values = df["Lat"]
y_values = df["Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="skyblue", edgecolors="black", alpha=0.90)

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-50,0), fontsize=20,color="red")

plt.xlim(df["Lat"].min()-3, df["Lat"].max()+3)
plt.ylim(y_values.min()-3, y_values.max()+3)

plt.title(f"City Latitude vs. Max Temperature ({curr_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")

plt.grid(b=True, which='major', color='grey', linestyle='-', alpha=0.70)

# print(f'the r value is: {regress_values}')

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
