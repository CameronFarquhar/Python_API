# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df = pd.read_csv('output_data/cities.csv')
df
# Out:
#      Unnamed: 0          City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0             0          hilo  19.7297 -155.0900  75.20        60           1
# 1             1     carnarvon -24.8667  113.6333  75.20       100          40
# 2             2  punta arenas -53.1500  -70.9167  69.80        49          40
# 3             3       ushuaia -54.8000  -68.3000  53.60        82          75
# 4             4    sobradinho -12.8333  -39.1000  84.02        63          55
# ..          ...           ...      ...       ...    ...       ...         ...
# 587         587   ramjibanpur  22.8333   87.6167  55.22        43           0
# 588         588         mansa  29.9833   75.3833  56.46        39           0
# 589         589       ipixuna  -1.7625  -48.8043  89.60        58          75
# 590         590      san juan -31.5375  -68.5364  73.40        33          93
# 591         591      tessalit  20.1986    1.0114  71.76        19          23
#
#       Wind Country        Date
# 0     4.61      US  1612293749
# 1    21.85      AU  1612293830
# 2    17.00      CL  1612293567
# 3    14.97      AR  1612293808
# 4     9.44      BR  1612293830
# ..     ...     ...         ...
# 587   3.40      IN  1612293902
# 588   6.08      IN  1612293902
# 589  10.36      BR  1612293902
# 590  11.59      AR  1612293769
# 591   8.84      ML  1612293903
#
# [592 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#grab locations by lat and long
locations = df[["Lat", "Lng"]]

#grab humidity column for weight
weight = df['Humidity']

# %%
#plot heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=weight,
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)
# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
narrow_cities =  df.loc[(df["Humidity"] < 80) & (df["Humidity"] > 10) & (df["Cloudiness"] == 0) & (df["Temp"] > 75.00) & (df["Temp"] < 80.00) & (df["Wind"] < 10.00)]
del narrow_cities["Unnamed: 0"]
narrow_cities
# Out:
#           City      Lat      Lng   Temp  Humidity  Cloudiness  Wind Country  \
# 14   coihaique -45.5752 -72.0662  75.20        43           0  4.61      CL
# 29     madimba -10.4000  40.3333  78.94        76           0  5.01      TZ
# 327      pisco -13.7000 -76.2167  77.00        65           0  8.05      PE
# 411      mecca  21.4267  39.8261  75.45        73           0  1.97      SA
# 442   calvinia -31.4707  19.7760  76.71        31           0  8.23      ZA
#
#            Date
# 14   1612293831
# 29   1612293833
# 327  1612293870
# 411  1612293843
# 442  1612293883

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
import json

hotel_df = []
target_type = "lodging"
coords = narrow_cities[["Lat","Lng"]]
radius = 5000
sets = 0
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for coord in coords.iterrows():
#     lat = coord[0] this gave me index. coord[1] gives both lat and lng
    lat_lng = coord[1]
    params = {
        "location": f'{lat_lng[0]},{lat_lng[1]}',
        "types": target_type,
        "radius": radius,
        "key": g_key
        }
    
    hotel = requests.get(base_url, params).json()
    
#     sets += 1
    
    print(json.dumps(hotel["results"], indent=4, sort_keys=True))

#     print(hotel["results"])

    
#     try:
#         hotel_df.append({
#             "Hotel Name":hotel["results"][sets]["name"]
#         })
# #         print(hotel["results"][0]["name"])
    
#     except KeyError:
#         pass

hotel_df
# Out:
# [
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5847244,
#                 "lng": -72.0744476
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5830373197085,
#                     "lng": -72.07323766970849
#                 },
#                 "southwest": {
#                     "lat": -45.5857352802915,
#                     "lng": -72.0759356302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Diego De Almagro Coyhaique",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 3264,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/100986717468937203401\">Isidora Urquiza Carter</a>"
#                 ],
#                 "photo_reference": "ATtYBwJ_KcRuQ1yJIKK-DaNCjf_mNmoWdLa7MiDGEs1KY4xTinuIPX8iJx1hgvmxFGS52IK7muwTc-ooZQAeObimbPtXsmaO8b8BX5_XPTn1Cn_qlbkznPWn1ko5gtbteafykhXNWwN-42HzOdum90l1gWUkxmqeBtAlHFeniwFayYtL_yh3",
#                 "width": 4912
#             }
#         ],
#         "place_id": "ChIJN6I2buXE8r0RU3kGpb9lSd4",
#         "plus_code": {
#             "compound_code": "CW8G+46 Coyhaique, Chile",
#             "global_code": "4769CW8G+46"
#         },
#         "rating": 4.3,
#         "reference": "ChIJN6I2buXE8r0RU3kGpb9lSd4",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 767,
#         "vicinity": "Ogana 1320, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.570766,
#                 "lng": -72.0737947
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.56941966970849,
#                     "lng": -72.0723892197085
#                 },
#                 "southwest": {
#                     "lat": -45.57211763029149,
#                     "lng": -72.0750871802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Dreams",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 2592,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/114987210562502763586\">Oscar PUERTA - Viajar es ViVir</a>"
#                 ],
#                 "photo_reference": "ATtYBwLo53eIinjavYUuFGuNBLLns8DpbAwFZwV-azHXmpJ7KrAbSPauRx8HZUXg9xojwgcaqN4Vgd_gRhFPYEMfOSdWkvKCh2gmtn4y8jl8nz-Ynrn_W61lgVtD8PnVPZqM1Bsb8zQqvshFYi8zdfcGFZ-5xqOxiRO8puUe6z_M4rsDSPkR",
#                 "width": 4608
#             }
#         ],
#         "place_id": "ChIJwej90sDE8r0RgCO4j4MlVq8",
#         "plus_code": {
#             "compound_code": "CWHG+MF Coyhaique, Chile",
#             "global_code": "4769CWHG+MF"
#         },
#         "rating": 4.4,
#         "reference": "ChIJwej90sDE8r0RgCO4j4MlVq8",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1049,
#         "vicinity": "Magallanes 131, Coyhaique, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5688867,
#                 "lng": -72.06424919999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5675464697085,
#                     "lng": -72.06295586970849
#                 },
#                 "southwest": {
#                     "lat": -45.5702444302915,
#                     "lng": -72.06565383029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Raices Bed and Breakfast",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 3096,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/112697876457071182703\">Pily Galleguillos Fuentes</a>"
#                 ],
#                 "photo_reference": "ATtYBwKqrk1EBjz7Io-WGlF2J_j5b_Y6bM6YXDUQieyxRT90N0sb6eSiUjwKS5VR8wxdBMTyenDtOR-In1_BV176_aoPfs-jTuMoxC7QrdGg_8atwE0lUn3_f00NHJZP1eeu_nxMYQmGzYuY1rBUMFFKXiVGp5FNezNF-Y-DdjKSbWpr8ae-",
#                 "width": 4128
#             }
#         ],
#         "place_id": "ChIJ_Q5-SLnE8r0RigricZtrWME",
#         "plus_code": {
#             "compound_code": "CWJP+C8 Coyhaique, Chile",
#             "global_code": "4769CWJP+C8"
#         },
#         "price_level": 2,
#         "rating": 4.6,
#         "reference": "ChIJ_Q5-SLnE8r0RigricZtrWME",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 79,
#         "vicinity": "General Baquedano 444, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.56805,
#                 "lng": -72.0648904
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.56669331970851,
#                     "lng": -72.06348231970848
#                 },
#                 "southwest": {
#                     "lat": -45.5693912802915,
#                     "lng": -72.0661802802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hotel los Nires",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/106776221135509345214\">Luis Andres Gonzalez Rojas</a>"
#                 ],
#                 "photo_reference": "ATtYBwI4Eu5EEidObu1G6c8Mdeben9yRxQIkm_II5D0ZD8fElJ0W9qghIZdyQ2aCU-z5GCjTKLvpQ3-CMkCrp6Qb5A-flpWf1nViN-T0lsZAJ_JZ88Of7QbegMOd_Aa-_98eEBFvL1H5-qNxWUqcVDJdlokR7VN1wT1aA8Z0A5YhiaDbDnGW",
#                 "width": 3024
#             }
#         ],
#         "place_id": "ChIJ0aPCarnE8r0RWX_NHo64zJ8",
#         "plus_code": {
#             "compound_code": "CWJP+Q2 Coyhaique, Chile",
#             "global_code": "4769CWJP+Q2"
#         },
#         "rating": 4.1,
#         "reference": "ChIJ0aPCarnE8r0RWX_NHo64zJ8",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 351,
#         "vicinity": "General Baquedano 315, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5699272,
#                 "lng": -72.0720901
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5687918197085,
#                     "lng": -72.0707752197085
#                 },
#                 "southwest": {
#                     "lat": -45.5714897802915,
#                     "lng": -72.07347318029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Apart Hotel Tehuelche Natura",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 4128,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101638338504532840255\">Isabel Margarita Molina Campa\u00f1a</a>"
#                 ],
#                 "photo_reference": "ATtYBwJhGVk3lJD3YL3qrmBSNeOarNHnbCU1TErmmlehRW-fUqu9glBCapSBIbrvs19jKL1wBLDJU0UJqm56UXj-3RUL9_lPjux86FDzE-YqmuENV-0V137gkf5Vg9EEgWXwI7dqMVBI8bJMqBVCSBMaQR872tvz973AnaewtC28J3_Gs89A",
#                 "width": 3096
#             }
#         ],
#         "place_id": "ChIJ0c6SJsfE8r0RMsFDgJzWtfI",
#         "plus_code": {
#             "compound_code": "CWJH+25 Coyhaique, Chile",
#             "global_code": "4769CWJH+25"
#         },
#         "rating": 4.5,
#         "reference": "ChIJ0c6SJsfE8r0RMsFDgJzWtfI",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 68,
#         "vicinity": "Doce de Octubre 108, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5709216,
#                 "lng": -72.06952640000002
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5695813197085,
#                     "lng": -72.06808951970851
#                 },
#                 "southwest": {
#                     "lat": -45.5722792802915,
#                     "lng": -72.07078748029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Cinco R\u00edos Lodge",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 2160,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/107386270687085491388\">Rodrigo Martinez</a>"
#                 ],
#                 "photo_reference": "ATtYBwIXA_ieEMHKt5SIxQyMBSjWYEP2Bgfizh_a_QPur_OAq_o6uoohqRuKTMm3p3mqW47VXmjsY4LD5eWxGrq-S4Q94dKA2G5ke9F6wA4bkVS45lCOREtweAhlePNcY1eDblhK2jralgra-QtSCupEQtVIufpoBC5BsHgtX0mZLdV3VdrQ",
#                 "width": 3840
#             }
#         ],
#         "place_id": "ChIJx635u7DE8r0RDbItKGgtJYA",
#         "plus_code": {
#             "compound_code": "CWHJ+J5 Coyhaique, Chile",
#             "global_code": "4769CWHJ+J5"
#         },
#         "rating": 4.3,
#         "reference": "ChIJx635u7DE8r0RDbItKGgtJYA",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 18,
#         "vicinity": "Plaza 65, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.58981000000001,
#                 "lng": -72.068596
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.58875166970851,
#                     "lng": -72.0673667197085
#                 },
#                 "southwest": {
#                     "lat": -45.59144963029151,
#                     "lng": -72.07006468029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Patagonia House",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 303,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/117448948260815226559\">Patagonia House</a>"
#                 ],
#                 "photo_reference": "ATtYBwJcaEFV1QNaoYnipV-UaeJAYXx2IaQn1XEuW0V4lX1qLp_eGde5DhbKUJtLOZlpB_G0wUcfCyeSC1FvuvLCDr7AdajpOlbhDGPIBDFtt8jng8VHqWeVaaU1L5gw3SewHs45uZLl-RsDLLm5gT9X42apfwdChpaO6vfFgoFn7R4tzqmy",
#                 "width": 800
#             }
#         ],
#         "place_id": "ChIJw1CGTPfE8r0RlME7TGshanY",
#         "plus_code": {
#             "compound_code": "CW6J+3H Coyhaique, Chile",
#             "global_code": "4769CW6J+3H"
#         },
#         "rating": 4.6,
#         "reference": "ChIJw1CGTPfE8r0RlME7TGshanY",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 100,
#         "vicinity": "Quinta 18 de Julio"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5831149,
#                 "lng": -72.07942779999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5817757197085,
#                     "lng": -72.07802306970848
#                 },
#                 "southwest": {
#                     "lat": -45.5844736802915,
#                     "lng": -72.0807210302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "The Patagonian Lodge",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 4160,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/117315270684381336770\">Mar\u00eda Contreras</a>"
#                 ],
#                 "photo_reference": "ATtYBwLzZ4RJRAxQtbkLDn7m2jO6BsdNKUbs3eutCyxllx1klfYxxSgG14axe_MeFEMy7ZqIhO_mIl7bKMBtJk3CG3LbtZt1t-QbeDcWZ_Uxpv5FtASgIG5CflpMrzaTAP0Lzj-BpjP7y9iK8p04I0GzOIcv9N053JzjrBlxLfYiVrIG_SE",
#                 "width": 3120
#             }
#         ],
#         "place_id": "ChIJn5PkRuTE8r0RH17nRYHST94",
#         "plus_code": {
#             "compound_code": "CW8C+Q6 Coyhaique, Chile",
#             "global_code": "4769CW8C+Q6"
#         },
#         "rating": 4.2,
#         "reference": "ChIJn5PkRuTE8r0RH17nRYHST94",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 85,
#         "vicinity": "Camino del Bosque 1170, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5711279,
#                 "lng": -72.0612975
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.56982581970849,
#                     "lng": -72.0599831197085
#                 },
#                 "southwest": {
#                     "lat": -45.57252378029149,
#                     "lng": -72.06268108029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "El Reloj Hotel",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 3463,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/109992249556502797221\">El Reloj Hotel</a>"
#                 ],
#                 "photo_reference": "ATtYBwLD9uxVRt44T1HB8VWZGnnIhBgQz_sAGRcYEInswLdiLGc2I-cEk5FxpaXU0eHXxijNPRVUHuuVXuQBiR3HR8iTn_L0_w5camTMI-Y6gnmgUkBc92-tguD4--xv9rCJXfwEBzfQAKZJA4z_-zzIOEJNno9c89jZ7oVX4KGeDkkhgeIA",
#                 "width": 5772
#             }
#         ],
#         "place_id": "ChIJKaeSKrzE8r0RM37bNJt94-M",
#         "plus_code": {
#             "compound_code": "CWHQ+GF Coyhaique, Chile",
#             "global_code": "4769CWHQ+GF"
#         },
#         "price_level": 2,
#         "rating": 4.4,
#         "reference": "ChIJKaeSKrzE8r0RM37bNJt94-M",
#         "scope": "GOOGLE",
#         "types": [
#             "travel_agency",
#             "lodging",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 180,
#         "vicinity": "General Baquedano 828, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5725291,
#                 "lng": -72.0769778
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5712061697085,
#                     "lng": -72.0755385197085
#                 },
#                 "southwest": {
#                     "lat": -45.5739041302915,
#                     "lng": -72.07823648029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hostel Truqueras Backpacker",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/105574533159344904695\">Natalia Mu\u00f1oz</a>"
#                 ],
#                 "photo_reference": "ATtYBwLl93O2Ee-G0Thpk8tP48d734o82u_5Yb4U5gB0xFzT2v42bQDqQ2xcn-mdyHKa3fl-QgzflBkAxh1VcszQNCYdOY1jLO1vPPABy2QRCziu5PyRusfhR_IEUT91h-9T3XQcovDtm_0NTaBVDBhw8Pmiu5inYubBqxIJizAthOHPglDB",
#                 "width": 3024
#             }
#         ],
#         "place_id": "ChIJ3xPygJbE8r0RvS6oWZJ_DMs",
#         "plus_code": {
#             "compound_code": "CWGF+X6 Coyhaique, Chile",
#             "global_code": "4769CWGF+X6"
#         },
#         "rating": 4.4,
#         "reference": "ChIJ3xPygJbE8r0RvS6oWZJ_DMs",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 85,
#         "vicinity": "Gabriela Mistral 469, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5737821,
#                 "lng": -72.0681931
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.57240986970849,
#                     "lng": -72.0669182697085
#                 },
#                 "southwest": {
#                     "lat": -45.57510783029149,
#                     "lng": -72.0696162302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Departamento Eusebio Lillo",
#         "obfuscated_type": [],
#         "place_id": "ChIJP875P8DE8r0RKFc4PBfXVSU",
#         "plus_code": {
#             "compound_code": "CWGJ+FP Coyhaique, Chile",
#             "global_code": "4769CWGJ+FP"
#         },
#         "reference": "ChIJP875P8DE8r0RKFc4PBfXVSU",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "vicinity": "Eusebio Lillo 366 interior Coyhaique, Ays\u00e9n"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5666676,
#                 "lng": -72.0727125
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5653356197085,
#                     "lng": -72.07137476970848
#                 },
#                 "southwest": {
#                     "lat": -45.56803358029149,
#                     "lng": -72.0740727302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Casa Balmaceda Backpackers",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 3464,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/115577706424876145153\">Luis E Silva C</a>"
#                 ],
#                 "photo_reference": "ATtYBwLRMjL-Q9hEw-iUkcDeThgYaH6zqc89YncqogPVfDkhtybpvr-TQa89_dyUoosRkpahFlRfpcC1_PVDrNpjLe5F_QAUZ72uiS21E5V_43diJsPvvLLWUZLwR3VhnzqgWPQuf-tgrX7sDMWV1F9XMWyqThKsAU4CwOM1ob4rbKejO2SO",
#                 "width": 4618
#             }
#         ],
#         "place_id": "ChIJ22si6MfE8r0RJ6a9BpI82AU",
#         "plus_code": {
#             "compound_code": "CWMG+8W Coyhaique, Chile",
#             "global_code": "4769CWMG+8W"
#         },
#         "rating": 3.8,
#         "reference": "ChIJ22si6MfE8r0RJ6a9BpI82AU",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 86,
#         "vicinity": "Jos\u00e9 Manuel Balmaceda 265, Coyhaique, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5784841,
#                 "lng": -72.0686229
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.57717641970849,
#                     "lng": -72.06729106970849
#                 },
#                 "southwest": {
#                     "lat": -45.57987438029149,
#                     "lng": -72.06998903029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Apartamentos Amueblados Patagonia Dove",
#         "obfuscated_type": [],
#         "place_id": "ChIJOyGWwOvE8r0Rz49OzOQlwXE",
#         "plus_code": {
#             "compound_code": "CWCJ+JH Coyhaique, Chile",
#             "global_code": "4769CWCJ+JH"
#         },
#         "rating": 5,
#         "reference": "ChIJOyGWwOvE8r0Rz49OzOQlwXE",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1,
#         "vicinity": "654 Los Coigues, Los Arrayanes, Coyhaique, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.591186,
#                 "lng": -72.088386
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.58985076970851,
#                     "lng": -72.0870138697085
#                 },
#                 "southwest": {
#                     "lat": -45.5925487302915,
#                     "lng": -72.0897118302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Caba\u00f1as R\u00edo Claro",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 3096,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/114276859124382476121\">Cecilia Merino</a>"
#                 ],
#                 "photo_reference": "ATtYBwJ7Nn1U2MlFRe2oFX7sfbTmRm2ciJz42YQA7KOxQjiCM9ON5hQxI-c3P2FLLiighx9I1Qkd9HIJMrgpAiov_H9DhXYTmdrkbMYu79qrOFWQip_IMy5qIQzXFr3jEuiyZzZrLiR9k8tNelfibifykm4wFmcWqgBHHYbKxGKNLtie_Z67",
#                 "width": 4128
#             }
#         ],
#         "place_id": "ChIJ-QbVkAPF8r0RTCMo9jTMjDc",
#         "plus_code": {
#             "compound_code": "CW56+GJ Coyhaique, Chile",
#             "global_code": "4769CW56+GJ"
#         },
#         "rating": 4.5,
#         "reference": "ChIJ-QbVkAPF8r0RTCMo9jTMjDc",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 66,
#         "vicinity": "Sector el Claro, Kil\u00f3metro 2, 5, Coihaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5686081,
#                 "lng": -72.065388
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5672691697085,
#                     "lng": -72.0640303197085
#                 },
#                 "southwest": {
#                     "lat": -45.5699671302915,
#                     "lng": -72.0667282802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hostal Ely",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 2736,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/111953235362563870610\">Eliana Erices</a>"
#                 ],
#                 "photo_reference": "ATtYBwI4nWSxl2FaBpT0A6UvBNn7i9DLQFm6ojJnVR3Sy_pXFQLuSQLdg_4naj2819cK5IEtDI-p76E-hsaBnCfxsT0J24HNeA0scw-8CC5mUl9tKVWMovmFK6Qi18BaR5n0A6LIi2XL3Guu9wQNyjt1j2jKbpQHLzxox1p7yw8lWh_s-UN-",
#                 "width": 3648
#             }
#         ],
#         "place_id": "ChIJ6XByPLnE8r0RGpLQ1Xf_KlY",
#         "plus_code": {
#             "compound_code": "CWJM+HR Coyhaique, Chile",
#             "global_code": "4769CWJM+HR"
#         },
#         "rating": 3.7,
#         "reference": "ChIJ6XByPLnE8r0RGpLQ1Xf_KlY",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 23,
#         "vicinity": "General Parra 41, Coyhaique, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5653812,
#                 "lng": -72.06545539999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.56404386970851,
#                     "lng": -72.06415861970848
#                 },
#                 "southwest": {
#                     "lat": -45.5667418302915,
#                     "lng": -72.0668565802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Nomades Hotel Boutique",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 3024,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/115478866383916354392\">Marlene Julio</a>"
#                 ],
#                 "photo_reference": "ATtYBwKvFw1AgJ4zQKxj9ri7ahFDsUQ5yBiKdt6zi1_VK4j4ETu_he_wH76ITJPxZEeUkIJPNJqfvC2Q_essL7E1zSzJkPQXept62v8NXKURo4EjvGBJotx65fK7VnZHCi52EJjWy-UEz2Ves36djx33PzsEQouQI8fShMAtvOwf4dmyQ3Kt",
#                 "width": 4032
#             }
#         ],
#         "place_id": "ChIJ_aaVTpjE8r0RImmqHHrh-DM",
#         "plus_code": {
#             "compound_code": "CWMM+RR Coyhaique, Chile",
#             "global_code": "4769CWMM+RR"
#         },
#         "rating": 4.5,
#         "reference": "ChIJ_aaVTpjE8r0RImmqHHrh-DM",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 91,
#         "vicinity": "84, General Baquedano 5951819, Coyhaique, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5487309,
#                 "lng": -72.0637967
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5472167697085,
#                     "lng": -72.0630042697085
#                 },
#                 "southwest": {
#                     "lat": -45.54991473029149,
#                     "lng": -72.0657022302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Caba\u00f1as los Canelos",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 1280,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101310211873606225081\">Am\u00e9rico Soto</a>"
#                 ],
#                 "photo_reference": "ATtYBwK0nwG2s6eSop-RDALmCqhaiuVptiVuEMbLyoqmOg4O2abY7zs71CvDWTb96lySFi_u-m7HMGdm9T45iITFngCHRFYADNn0uFpiLO1RDdRYjk7jREMef2IE9ZJYSjSEV10T83X-L8IUG4LzAPZlNPRDGeoa3Sg7do8G0bs_u6KZL-H0",
#                 "width": 1098
#             }
#         ],
#         "place_id": "ChIJVbHyNfnE8r0RuWZvl1KJ-8Y",
#         "plus_code": {
#             "compound_code": "FW2P+GF Coyhaique, Chile",
#             "global_code": "4769FW2P+GF"
#         },
#         "rating": 4.4,
#         "reference": "ChIJVbHyNfnE8r0RuWZvl1KJ-8Y",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 12,
#         "vicinity": "km 2 camino a puerto aysen km 2"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5742949,
#                 "lng": -72.06729659999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5729854697085,
#                     "lng": -72.0659707697085
#                 },
#                 "southwest": {
#                     "lat": -45.5756834302915,
#                     "lng": -72.0686687302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "No tiene nombre",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 1920,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/114047405331904650216\">Damian Olivares</a>"
#                 ],
#                 "photo_reference": "ATtYBwLGoj-mMRIwrgEKSKbalvOPxw7FpQrC5Mn92b7IrDaSrQj8jZbkxAQ6ZUiuJxIMY-4__HSCD7x66XwThx5FOJl4UasQ6BG13aPtlATrYu6ao-XKML9DZjgEsKwAdwokgDR403KpHicO6OdYIf2YAgPA0BfoIM56E-Jexf-EE2dOfEYE",
#                 "width": 1080
#             }
#         ],
#         "place_id": "ChIJdRsUGsDE8r0R2mK5beEU7gU",
#         "plus_code": {
#             "compound_code": "CWGM+73 Coyhaique, Chile",
#             "global_code": "4769CWGM+73"
#         },
#         "rating": 5,
#         "reference": "ChIJdRsUGsDE8r0R2mK5beEU7gU",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1,
#         "vicinity": "Ram\u00f3n Freire 590 Coyhaique, Ays\u00e9n"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.5719485,
#                 "lng": -72.07265629999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5706305197085,
#                     "lng": -72.07131206970848
#                 },
#                 "southwest": {
#                     "lat": -45.5733284802915,
#                     "lng": -72.0740100302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "HUELLAS Y SENDEROS HOTEL",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 4032,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/103388848789454240950\">Einer Pregnan</a>"
#                 ],
#                 "photo_reference": "ATtYBwKSzauLKXLuk4U_hkwWTU3DTGAVlTcpBqz-Pt5_uX63hAd4kxf9EG7G_HP9-F3fI1xDksEPmCwpjGPbR4uliO7xkSb4Z8ARuJu5UoEyM9bFnp9uqnRB2aKgnrqBgzTsrOdkt6zvnqENL23tm4vFzm20OvZ9AGm58kZQhZwVJGlTNlaJ",
#                 "width": 3024
#             }
#         ],
#         "place_id": "ChIJUYiVP8HE8r0Rj_TVzoOOhcU",
#         "plus_code": {
#             "compound_code": "CWHG+6W Coyhaique, Chile",
#             "global_code": "4769CWHG+6W"
#         },
#         "rating": 5,
#         "reference": "ChIJUYiVP8HE8r0Rj_TVzoOOhcU",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 8,
#         "vicinity": "Francisco Bilbao 178, Coyhaique"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -45.57601469999999,
#                 "lng": -72.06993899999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -45.5746433197085,
#                     "lng": -72.0685761197085
#                 },
#                 "southwest": {
#                     "lat": -45.5773412802915,
#                     "lng": -72.0712740802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Preu Hostal",
#         "obfuscated_type": [],
#         "place_id": "ChIJZ7YAberE8r0R1W_dD4V6zP0",
#         "plus_code": {
#             "compound_code": "CWFJ+H2 Coyhaique, Chile",
#             "global_code": "4769CWFJ+H2"
#         },
#         "rating": 3.3,
#         "reference": "ChIJZ7YAberE8r0R1W_dD4V6zP0",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 4,
#         "vicinity": "Lautaro 483, Coyhaique, Coyhaique"
#     }
# ]
# []
# [
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7078686,
#                 "lng": -76.1989899
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7065197697085,
#                     "lng": -76.1976348197085
#                 },
#                 "southwest": {
#                     "lat": -13.7092177302915,
#                     "lng": -76.2003327802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hotel San Isidro Oficial",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 3000,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/114798277153673078529\">therius rubio</a>"
#                 ],
#                 "photo_reference": "ATtYBwKFWzDcxMQIUeL9nED3v2aMk5lGOs7ax3yUJHU6PCEp1KpIwFUts-k254GkM1EJNnxjUF9VlIuu7baCenK0GklNBqH8rPNfkwj9JEOtamM4CoIo8b3ig8Hgd54JFrd6_Z0F7zwv7OAQqT-eL5KZwI30twGgHvvGTE-YamEshPwsKQaU",
#                 "width": 4000
#             }
#         ],
#         "place_id": "ChIJf1yknF9vEJERDibhidu8nGw",
#         "plus_code": {
#             "compound_code": "7RR2+VC Pisco, Peru",
#             "global_code": "57R57RR2+VC"
#         },
#         "rating": 3.9,
#         "reference": "ChIJf1yknF9vEJERDibhidu8nGw",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 343,
#         "vicinity": "Calle, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7093021,
#                 "lng": -76.2056082
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7079970197085,
#                     "lng": -76.2042617697085
#                 },
#                 "southwest": {
#                     "lat": -13.7106949802915,
#                     "lng": -76.2069597302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hosteria del Monasterio",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 2592,
#                 "html_attributions": [
#                     "Photos are copyrighted by their owners"
#                 ],
#                 "photo_reference": "ATtYBwIvxu8_6ABigRpB9Wt-E6t-lkltZD3T6AnwknwxC_NEHKYRzHcJmzsMAppWA9OWdnEMRQvarS8JemlO2Ih2pEE8Y2580E9by8dEPb08MeaynJsPXZvgoNw_M6A93LFgp4Z-mbqgCL9c12YEQfcfdgWFxrGXN0fOgXDXyu4_tV-z_9Bu",
#                 "width": 4608
#             }
#         ],
#         "place_id": "ChIJZV4RdIplEJERRnKbz7F2y28",
#         "plus_code": {
#             "compound_code": "7QRV+7Q Pisco, Peru",
#             "global_code": "57R57QRV+7Q"
#         },
#         "rating": 3.6,
#         "reference": "ChIJZV4RdIplEJERRnKbz7F2y28",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 44,
#         "vicinity": "Calle Bolognesi 326 ( a dos cuadras de la plaza de armas), Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7095036,
#                 "lng": -76.20392439999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7081488697085,
#                     "lng": -76.20257521970849
#                 },
#                 "southwest": {
#                     "lat": -13.7108468302915,
#                     "lng": -76.2052731802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hostal Tambo Colorado",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 2304,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/104459390112929974599\">Hostal Tambo Colorado</a>"
#                 ],
#                 "photo_reference": "ATtYBwJ2zpoq4mu5d8PNqTCECKcksB0vOPB7AgSDfqRNfdO4UrTYs0mBu0B0QJajDGTyhWvOCa4YtF790wPpHMLXb7clioYu2nKDaSiv3S6krB_wpRp86MTUbzQluqFX_kybl7ifEJ3Dv_swzxbR6w84MLykykhuKpP1bYg8M3-Ytl0OEc1i",
#                 "width": 3456
#             }
#         ],
#         "place_id": "ChIJ-_I7hoplEJER_PYm4blEQiw",
#         "plus_code": {
#             "compound_code": "7QRW+5C Pisco, Peru",
#             "global_code": "57R57QRW+5C"
#         },
#         "rating": 4.2,
#         "reference": "ChIJ-_I7hoplEJER_PYm4blEQiw",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 253,
#         "vicinity": "Francisco Bolognesi 159, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7312697,
#                 "lng": -76.2227707
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7299503697085,
#                     "lng": -76.22143266970849
#                 },
#                 "southwest": {
#                     "lat": -13.7326483302915,
#                     "lng": -76.2241306302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Las Olas",
#         "obfuscated_type": [],
#         "place_id": "ChIJj08xlp9lEJERiZINAgozsUE",
#         "plus_code": {
#             "compound_code": "7Q9G+FV Pisco, Peru",
#             "global_code": "57R57Q9G+FV"
#         },
#         "rating": 5,
#         "reference": "ChIJj08xlp9lEJERiZINAgozsUE",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1,
#         "vicinity": "Calle, Miguel Grau N\u00b0156, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7056347,
#                 "lng": -76.207279
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7042878697085,
#                     "lng": -76.2059302197085
#                 },
#                 "southwest": {
#                     "lat": -13.7069858302915,
#                     "lng": -76.20862818029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "La Casa de Lourdes",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 4160,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101217838187635148534\">Marilu Tejeda</a>"
#                 ],
#                 "photo_reference": "ATtYBwK6VzqFK-wrKrA_DDGcBkuQCK4O4UfNSnO3h3nL4MF2Vr45lYMJHCH999S5-isxyHCRc-sDUbj0YKWFJ_vm6d8RuP87I3gZziyc1C5ANn98u2FQ0kdDwnexg-VWkid6x8RTd805u1LOTBrwUY0cHuG7plTbuJu5iU1WLPfCIEjPTY8R",
#                 "width": 3120
#             }
#         ],
#         "place_id": "ChIJ-UlBfWFvEJERtWGpqObAfyA",
#         "plus_code": {
#             "compound_code": "7QVV+P3 Pisco, Peru",
#             "global_code": "57R57QVV+P3"
#         },
#         "rating": 4,
#         "reference": "ChIJ-UlBfWFvEJERtWGpqObAfyA",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 16,
#         "vicinity": "Urb. Pesca Per\u00fa Mz. P - Lote 15, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7114868,
#                 "lng": -76.2022135
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7101874697085,
#                     "lng": -76.20086756970849
#                 },
#                 "southwest": {
#                     "lat": -13.7128854302915,
#                     "lng": -76.20356553029151
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Posada Gino",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 765,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/104930441629687670686\">Posada Gino</a>"
#                 ],
#                 "photo_reference": "ATtYBwIFMgJHH9JW7XuMus5NTSPaqQq979ajMetBobQrAmLnDnZ5rqQIbu7GmEfpFf7hQ1vre7AC4aE79EuQsJpxxr4Pn2B6UOQ_oYDtcAw2cwpoTHhqitd6mPJMQQtb-hrxVsJEiQ4FyLY8ZyGhlR3aZYoN5u2f6k4tRy9qQJ01wkX_t4fJ",
#                 "width": 1228
#             }
#         ],
#         "place_id": "ChIJR6bXN4plEJERshGmHEvsCBw",
#         "plus_code": {
#             "compound_code": "7QQX+C4 Pisco, Peru",
#             "global_code": "57R57QQX+C4"
#         },
#         "rating": 4.3,
#         "reference": "ChIJR6bXN4plEJERshGmHEvsCBw",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 114,
#         "vicinity": "Calle Arequipa 241, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7077679,
#                 "lng": -76.20521389999999
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7064697197085,
#                     "lng": -76.2038110197085
#                 },
#                 "southwest": {
#                     "lat": -13.7091676802915,
#                     "lng": -76.2065089802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hostal La Portada",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 480,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/103422444281068072297\">Maria Del Carmen Collantes Chuman</a>"
#                 ],
#                 "photo_reference": "ATtYBwK15Y93uwx-77Qw8ccv1k6NfBwovDcpQaz3csEcviFlgWDJAN5Q4YL-p9f2o3cOnOqlSW4y1vw2f2nLoIj8vIUHq9FKSjujaztB4iGFYW6tNORoLWUj04Ovib6GwRHJEWhkKjz3x-WuFrcxd1qdDeLM5Trk8oBDCHM9Tm5PiNvgYYAE",
#                 "width": 640
#             }
#         ],
#         "place_id": "ChIJ2ZmXyWFvEJERcmsbeNk383E",
#         "plus_code": {
#             "compound_code": "7QRV+VW Pisco, Peru",
#             "global_code": "57R57QRV+VW"
#         },
#         "rating": 3.9,
#         "reference": "ChIJ2ZmXyWFvEJERcmsbeNk383E",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 20,
#         "vicinity": "Calle Capitan Alipio Ponce Vasquez 250, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7099185,
#                 "lng": -76.2145601
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7083883697085,
#                     "lng": -76.2132055197085
#                 },
#                 "southwest": {
#                     "lat": -13.7110863302915,
#                     "lng": -76.2159034802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Embassy Beach",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 856,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/100346583801953608407\">Embassy Beach</a>"
#                 ],
#                 "photo_reference": "ATtYBwIFCm-K5sjBY2XKPasD7KPAou-GHFvm-E58Se2vVaNkaYBqll4AQNiQYOJfTyNEb648u0ZZ2nruRqgN6O5qHO88z4ZiHTyXxyA17U_eQ6dznB3fh5PK--xlIvMz51q1NZrGwQqkyp5ZvaaBY-zLPIiVo7k6hmSL4b9lCHe0XcYtTGNO",
#                 "width": 1029
#             }
#         ],
#         "place_id": "ChIJL0IYjYdlEJERTKwalyNiwXA",
#         "plus_code": {
#             "compound_code": "7QRP+25 Pisco, Peru",
#             "global_code": "57R57QRP+25"
#         },
#         "rating": 3.8,
#         "reference": "ChIJL0IYjYdlEJERTKwalyNiwXA",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 220,
#         "vicinity": "Jose De San Martin 1119, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.7103544,
#                 "lng": -76.2045036
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -13.7090520697085,
#                     "lng": -76.20315671970849
#                 },
#                 "southwest": {
#                     "lat": -13.7117500302915,
#                     "lng": -76.2058546802915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Hostal El Candelabro",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 2048,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/102059883632801503333\">Hostal El Candelabro</a>"
#                 ],
#                 "photo_reference": "ATtYBwJYHCY3BP08bWT6v9xTnFQ8WABhl2HOe3RVGS516UJu8GqdgfTO4z7BCjflNtX7CxlArh3HHwjrkWJDIBkzA95s1354cp-OlNAYj3KtqcL8o3ufW-XmI0PM7dhpoYFhpJ156QwbBFyr9YuEvRLw_lKQetmjNDbs-319N7LfWGUrDt0M",
#                 "width": 1682
#             }
#         ],
#         "place_id": "ChIJM8yZaYplEJERzIxeUSaqrRQ",
#         "plus_code": {
#             "compound_code": "7QQW+V5 Pisco, Peru",
#             "global_code": "57R57QQW+V5"
#         },
#         "rating": 4,
#         "reference": "ChIJM8yZaYplEJERzIxeUSaqrRQ",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 194,
#         "vicinity": "Jiron Callao 190, Pisco"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -13.708293,
# ...
#             "store",
#             "establishment"
#         ],
#         "user_ratings_total": 74,
#         "vicinity": "17 Strauss Avenue, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4691624,
#                 "lng": 19.7758074
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4678267197085,
#                     "lng": 19.7771964802915
#                 },
#                 "southwest": {
#                     "lat": -31.4705246802915,
#                     "lng": 19.7744985197085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Calvania Caravan Park",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": false
#         },
#         "place_id": "ChIJrc0HYDEJLhwR4kTcf4oIzZs",
#         "plus_code": {
#             "compound_code": "GQJG+88 Calvinia, South Africa",
#             "global_code": "4FWXGQJG+88"
#         },
#         "reference": "ChIJrc0HYDEJLhwR4kTcf4oIzZs",
#         "scope": "GOOGLE",
#         "types": [
#             "rv_park",
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "vicinity": "Tuin Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.473244,
#                 "lng": 19.775074
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4719004197085,
#                     "lng": 19.77637283029151
#                 },
#                 "southwest": {
#                     "lat": -31.4745983802915,
#                     "lng": 19.7736748697085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "The Calvinian Hotel",
#         "obfuscated_type": [],
#         "place_id": "ChIJsaZAiWUILhwRUVsn0BVL1P0",
#         "plus_code": {
#             "compound_code": "GQGG+P2 Calvinia, South Africa",
#             "global_code": "4FWXGQGG+P2"
#         },
#         "reference": "ChIJsaZAiWUILhwRUVsn0BVL1P0",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "vicinity": "Cnr. Water &, Dorp Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.467087,
#                 "lng": 19.776291
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4658396197085,
#                     "lng": 19.7776544302915
#                 },
#                 "southwest": {
#                     "lat": -31.4685375802915,
#                     "lng": 19.7749564697085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Wild Tree B&B [Calvinia]",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 1280,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101849270450660416813\">Francois Janse Van Vuuren</a>"
#                 ],
#                 "photo_reference": "ATtYBwL52mjHqZztrL2R3FiztDhQm_db2GgVyHnCb7nG-Q-QIBBdRjsgmgeAFi_EsHAFQJlSXZH1qH6-kjT24q8-_ZIVY_5FhCGtPBzwKQjgWNHg0xMSGUnTjYQFY3sAloPyC12HPCup_rhm5uXXX39hKjJVQDhyf9vj4tJu2mAIav_fMb4q",
#                 "width": 1920
#             }
#         ],
#         "place_id": "ChIJwyRf5WMILhwR8B-KDCMvWgA",
#         "plus_code": {
#             "compound_code": "GQMG+5G Calvinia, South Africa",
#             "global_code": "4FWXGQMG+5G"
#         },
#         "rating": 4.4,
#         "reference": "ChIJwyRf5WMILhwR8B-KDCMvWgA",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 27,
#         "vicinity": "25 Stasie Way, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4733239,
#                 "lng": 19.771252
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4719398697085,
#                     "lng": 19.7725961802915
#                 },
#                 "southwest": {
#                     "lat": -31.4746378302915,
#                     "lng": 19.76989821970849
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Visagie Park",
#         "obfuscated_type": [],
#         "place_id": "ChIJ-S82b2UILhwRu1SfYOVJC9g",
#         "plus_code": {
#             "compound_code": "GQGC+MG Calvinia, South Africa",
#             "global_code": "4FWXGQGC+MG"
#         },
#         "rating": 4.1,
#         "reference": "ChIJ-S82b2UILhwRu1SfYOVJC9g",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 8,
#         "vicinity": "Hantam Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4756138,
#                 "lng": 19.7749544
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4741967197085,
#                     "lng": 19.7762952802915
#                 },
#                 "southwest": {
#                     "lat": -31.4768946802915,
#                     "lng": 19.7735973197085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "The Calvinian Lodge",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 2848,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/107987635606969902111\">The Calvinian Lodge</a>"
#                 ],
#                 "photo_reference": "ATtYBwKyYvXXN5v0Kp94Xe_nrOMe_nZBWqBSHH87_vUheJTqX0sQ5Vqyryt5Mhwabpww3DW4DTnHRYbB82Z6wjFEn_4wHR_gXX3MFVDQpGm-uhzioG0Rlh2E3Rba6TodCaqa0Ubr8Wu0ZfTf6htOIYeDLWJVof7jFwUmmazRSJu7HlzWwdil",
#                 "width": 4272
#             }
#         ],
#         "place_id": "ChIJy_uDGm8ILhwRyyAJFqCYX44",
#         "plus_code": {
#             "compound_code": "GQFF+QX Calvinia, South Africa",
#             "global_code": "4FWXGQFF+QX"
#         },
#         "rating": 3.3,
#         "reference": "ChIJy_uDGm8ILhwRyyAJFqCYX44",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 9,
#         "vicinity": "19 Water Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4657022,
#                 "lng": 19.7746882
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4643421197085,
#                     "lng": 19.7756284302915
#                 },
#                 "southwest": {
#                     "lat": -31.4670400802915,
#                     "lng": 19.7729304697085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Katryns Calvania B&B",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 480,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/113925358534465154289\">Katryns calvinia B&amp;B</a>"
#                 ],
#                 "photo_reference": "ATtYBwLBL9x1mUw33kZNYryaBFSx6rI1s77iW2tSgEU-9TYfgDB7AmV0tjxq2z267d62F07wVJZqG4xi1icdehHGsXr3TxP46duayD17GQRwexasQAsVYZYUtIzLB5a91_JHQU_DLkgaoJ38R1aO-IfUJYiWG4dHWlAUQqsY0TzXJ73RLnTS",
#                 "width": 480
#             }
#         ],
#         "place_id": "ChIJa1fyAGMILhwRn7Gh65_CPp0",
#         "plus_code": {
#             "compound_code": "GQMF+PV Calvinia, South Africa",
#             "global_code": "4FWXGQMF+PV"
#         },
#         "rating": 4.5,
#         "reference": "ChIJa1fyAGMILhwRn7Gh65_CPp0",
#         "scope": "GOOGLE",
#         "types": [
#             "beauty_salon",
#             "cafe",
#             "lodging",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "store",
#             "establishment"
#         ],
#         "user_ratings_total": 23,
#         "vicinity": "13 Holden Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4757398,
#                 "lng": 19.7738097
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4743162197085,
#                     "lng": 19.7751481302915
#                 },
#                 "southwest": {
#                     "lat": -31.4770141802915,
#                     "lng": 19.7724501697085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Mile 250",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": false
#         },
#         "photos": [
#             {
#                 "height": 2848,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/101024924954465823515\">Wyona Victor</a>"
#                 ],
#                 "photo_reference": "ATtYBwIrUbM5guoii_tRsnj9pb990vx2MBbBo7-tJ3QnrZWh3ys150eC8MdNPTmPR-M4XRLWQ4v7-ZbihF2UNyWtO3GVTNiPLkGItbzw_7G9PJEgUodtdZNOE8bfUJxT1w8P6Uy-J6r4WlXkO1VafyHOkwWBOO9aAC2eqEX-FFjpMc0gyNHt",
#                 "width": 4272
#             }
#         ],
#         "place_id": "ChIJ9ejzrmAJLhwRYCUvSjBH0Qk",
#         "plus_code": {
#             "compound_code": "GQFF+PG Calvinia, South Africa",
#             "global_code": "4FWXGQFF+PG"
#         },
#         "rating": 5,
#         "reference": "ChIJ9ejzrmAJLhwRYCUvSjBH0Qk",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 1,
#         "vicinity": "29 Water Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.46580429999999,
#                 "lng": 19.7786237
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4642920197085,
#                     "lng": 19.7799514302915
#                 },
#                 "southwest": {
#                     "lat": -31.4669899802915,
#                     "lng": 19.7772534697085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Tontelbossie Selfsorg",
#         "obfuscated_type": [],
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 500,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/106810428950398764016\">Van Van Der Westhuysen</a>"
#                 ],
#                 "photo_reference": "ATtYBwJiEzivyrmal5VjhhSgOzkf0A_0chOl8tTfiBcWdzzbi7VBvMR_GIrJkTV-i1bf3HjtpmMuNR_5ZjcqVagDAAFx7eOWttqAE4xsRe2Ctc9zzbus67z-uLQmLQgG5WDbtuaBxhN5hEwprx9h2teIR4paKVYf6i_1gHCcvUoJ_-rIRzji",
#                 "width": 700
#             }
#         ],
#         "place_id": "ChIJ6RmXFGEILhwRq-6Ix9zm6Ro",
#         "plus_code": {
#             "compound_code": "GQMH+MC Calvinia, South Africa",
#             "global_code": "4FWXGQMH+MC"
#         },
#         "rating": 4.2,
#         "reference": "ChIJ6RmXFGEILhwRq-6Ix9zm6Ro",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 17,
#         "vicinity": "25 De Villiers Street, Calvinia, Brandvlei"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4743889,
#                 "lng": 19.7710753
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4729796197085,
#                     "lng": 19.7724278802915
#                 },
#                 "southwest": {
#                     "lat": -31.4756775802915,
#                     "lng": 19.7697299197085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Calvinia Guesthouse",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 3120,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/112825723648857715105\">Isolet Jansen</a>"
#                 ],
#                 "photo_reference": "ATtYBwK7LO6M2nRyAR-NOm1X-Wh3tz7wL6SRaiKW1C2tLqMhUh9zn_aKQBAVCIpho0eDkpiWtKM_Pwo6YbsDwSxptXJDeUHKANlhkfQ8GyX6GhuAu_GCPTl-ov79vql1RkfxSz74RnON6Oj1CAZiXsngveYFlkh5cZZz4IOvxxjUJCrhUXkW",
#                 "width": 4160
#             }
#         ],
#         "place_id": "ChIJ_____z8ILhwRmQ7aF3oLMQk",
#         "plus_code": {
#             "compound_code": "GQGC+6C Calvinia, South Africa",
#             "global_code": "4FWXGQGC+6C"
#         },
#         "rating": 4.3,
#         "reference": "ChIJ_____z8ILhwRmQ7aF3oLMQk",
#         "scope": "GOOGLE",
#         "types": [
#             "lodging",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 28,
#         "vicinity": "47 Stigling Street, Calvinia"
#     },
#     {
#         "business_status": "OPERATIONAL",
#         "geometry": {
#             "location": {
#                 "lat": -31.4659192,
#                 "lng": 19.7794166
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": -31.4647037197085,
#                     "lng": 19.7807848802915
#                 },
#                 "southwest": {
#                     "lat": -31.4674016802915,
#                     "lng": 19.7780869197085
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#         "name": "Klipwerf Self Catering & Camping",
#         "obfuscated_type": [],
#         "photos": [
#             {
#                 "height": 581,
#                 "html_attributions": [
#                     "<a href=\"https://maps.google.com/maps/contrib/107284300926707303541\">Klipwerf Self Catering &amp; Camping</a>"
#                 ],
#                 "photo_reference": "ATtYBwKxr0dD_mW_sT7FYX29aipwD-ounA6x9rGK6afGapq2_loh26G54QZNaaeGu994QrqVf3c5XZdPJmMfrhm6IUsnWu8OyUs82QGMuaQJX70-rfnpu5jSyd4SK4l7hfJvLNeSAVJBM3ZahYYC7HyffCvKE9w4w0bE4zOfXPswWSCTR8nb",
#                 "width": 1032
#             }
#         ],
#         "place_id": "ChIJ7ZNkGGEILhwRb7beaMcmJm4",
#         "plus_code": {
#             "compound_code": "GQMH+JQ Calvinia, South Africa",
#             "global_code": "4FWXGQMH+JQ"
#         },
#         "rating": 4.2,
#         "reference": "ChIJ7ZNkGGEILhwRb7beaMcmJm4",
#         "scope": "GOOGLE",
#         "types": [
#             "campground",
#             "lodging",
#             "park",
#             "point_of_interest",
#             "establishment"
#         ],
#         "user_ratings_total": 57,
#         "vicinity": "16 Paul Kruger Street, Calvinia"
#     }
# ]
# []

# %%
import json
hotel_df = []

target_type = "lodging"
coords = "-45.5752,-72.0662"
radius = 5000

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": coords,
    "types": target_type,
    "radius": radius,
    "key": g_key
        }
hotel = requests.get(base_url, params).json()

print(hotel["results"][0]["name"])
# Out:
# Diego De Almagro Coyhaique

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-113-a6bb01fbea11> in <module>
#      13         }
#      14     hotel = requests.get(base_url, params).json()
# ---> 15     print(hotel["results"][0]["name"])
#
# IndexError: list index out of range

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
